# %% [markdown]
# # 자연어처리_뉴스토픽분류 AI 경진대회

# %%
# !pip install konlpy

# %%
# ! pip install lightgbm

# %% [markdown]
# ## 라이브러리 로드

# %%
import pandas as pd
import re
from konlpy.tag import Okt,Mecab
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score,f1_score

from sklearn.naive_bayes import MultinomialNB
from lightgbm import LGBMClassifier

# %% [markdown]
# ## 데이터 로드

# %%
# 데이터 불러오기
train = pd.read_csv('Dataset/train_data.csv')
test = pd.read_csv('Dataset/test_data.csv')

# %%
# 데이터 확인
train.tail()
# Out:
#        index                               title  topic_idx
# 45649  45649        KB금융 미국 IB 스티펠과 제휴…선진국 시장 공략          1
# 45650  45650     1보 서울시교육청 신종코로나 확산에 개학 연기·휴업 검토          2
# 45651  45651         게시판 키움증권 2020 키움 영웅전 실전투자대회          1
# 45652  45652                   답변하는 배기동 국립중앙박물관장          2
# 45653  45653  2020 한국인터넷기자상 시상식 내달 1일 개최…특별상 김성후          2

# %%
# 결측치 확인
train.isnull().sum()
# Out:
# index        0
# title        0
# topic_idx    0
# dtype: int64

# %%
# label 비율 확인
train.topic_idx.value_counts()
# Out:
# 4    7629
# 2    7362
# 5    6933
# 6    6751
# 1    6222
# 3    5933
# 0    4824
# Name: topic_idx, dtype: int64

# %%
okt=Okt()

# %%
# 조사, 어미, 구두점 제거
def func(text):
    clean = []
    for word in okt.pos(text, stem=True): #어간 추출
        if word[1] not in ['Josa', 'Eomi', 'Punctuation','Suffix','Number']: #조사, 어미, 구두점 제외 
            clean.append(word[0])
    
    
    return " ".join(clean) 

train['title'] = train['title'].apply(lambda x : func(x))
test['title'] = test['title'].apply(lambda x : func(x))

# %%
train['title']
# Out:
# 0                   인천 → 핀란드 항공기 결항 휴가 철 여행객 분통
# 1                     실리콘밸리 넘어서다 구글 들이다 美 전역 거점
# 2               이란 외무 긴장 완화 해결 책 미국 경제 전쟁 멈추다 것
# 3        NYT 클린턴 측근 韓 기업 특수 관계 조명 공과 사 맞다 물리 종합
# 4                     시진핑 트럼프 중미 무역 협상 조속 타결 희망
#                           ...
# 45649             KB 금융 미국 IB 스티 펠 제휴 선진국 시장 공략
# 45650           보 서울시 교육청 신종 코로나 확산 개학 연기 휴업 검토
# 45651              게시판 키우다 증권 키우다 영웅 전 실전 투자 대회
# 45652                      답변 하다 배 기동 국립 중앙 박물관
# 45653               한국 인터넷 기자 시상식 내달 개최 특별상 김성후
# Name: title, Length: 45654, dtype: object

# %%
# 불용어 리스트 생성
stopwords = ['의', '가', '이', '은', '들', '는','…...','·','→','되다','때','시','보','전','첫','간','안',
             '좀', '잘', '걍', '과', '도', '을','를', '명','돼다','곳','듯','속',
             '...','.',',','…','종합','·','냐','것', '→','↑','위','급','회','각','후','내',
             '로','으로', '자', '에', '와', '한', '하다']

# %%
X_train = [] 
for sentence in train['title']: 
    temp_X = [] 
    temp_X = okt.morphs(sentence, stem=True) # 토큰화 
    temp_X = [word for word in temp_X if not word in stopwords] # 불용어 제거 
    X_train.append(temp_X) 
    
X_test = [] 
for sentence in test['title']: 
    temp_X = [] 
    temp_X = okt.morphs(sentence, stem=True) # 토큰화 
    temp_X = [word for word in temp_X if not word in stopwords] # 불용어 제거 
    X_test.append(temp_X)

# %%
X_train
# Out:
# [['인천', '핀란드', '항공기', '결항', '휴가', '철', '여행객', '분통'],
#  ['실리콘밸리', '넘어서다', '구글', '들이다', '美', '전역', '거점'],
#  ['이란', '외무', '긴장', '완화', '해결', '책', '미국', '경제', '전쟁', '멈추다'],
#  ['NYT', '클린턴', '측근', '韓', '기업', '특수', '관계', '조명', '공과', '사', '맞다', '물리'],
#  ['시진핑', '트럼프', '중미', '무역', '협상', '조속', '타결', '희망'],
#  ['팔레스타인', '가자지구', '세', '소년', '이스라엘군', '총격', '사망'],
#  ['인도', '파키스탄', '공습', '테러', '캠프', '폭격'],
#  ['美',
#   '대선',
#   'TV',
#   '토론',
#   '음담패설',
#   '만회',
#   '실패',
#   '트럼프',
#   '사과',
#   '대신',
#   '빌다',
#   '클린턴',
#   '공격',
#   '역효과'],
#  ['푸틴', '한반도', '상황', '진전', '방안', '김정은', '위원장', '논의'],
#  ['특검', '면죄부', '받다', '트럼프', '스캔들', '보도', '언론', '맹공', '국민', '적'],
#  ['日', '오키나와', '열', '리다', '강제', '징용', '노동자', '추도'],
#  ['이란', '최고', '지도자', '모욕', '혐의', '미국인', '징역', '선고'],
#  ['카니발', '축제', '보다', '가다', '브라질', '리우', '대형', '유람선', '행렬'],
#  ['美', '올랜도', '병원', '최악', '총기', '테러', '부상', '치료', '비', '받다'],
#  ['日', '대기업', '올해', '평균', '임금', '인상'],
#  ['WMO', '엘니뇨', '여전하다', '강력', '기', '소멸'],
#  ['이스라엘', '네타냐후', '유대교도', '병역', '문제', '연정', '협상', '진통'],
#  ['UAE', '사우디', '美', '호르무즈', '호위', '연합', '참여'],
#  ['사우디', '오만하다', '유조선', '공격', '예멘', '반군', '연결', '이란', '겨냥'],
#  ['개천', '용', '나와라', '美', '사업가', '모교', '장학금', '기부'],
#  ['EU', '브렉', '시트', '합의', '일', '많다', '英', '경고'],
#  ['스팍스', '운용', '일본', '디플레', '벗어나다', '새롭다', '도약', '준비', '중'],
#  ['트럼프', '총', '기', '난사', '惡', '공격', '총기', '규제', '초당', '협력', '촉구'],
#  ['NBA', '카지노', '업체', '스폰서', '계약', '美', '프로스포츠', '사상', '처음'],
#  ['오바마', '대통령', '퇴임', '워싱턴', 'DC', '사무실', '개다', '예정'],
#  ['美', '전문가', '트럼프', '정부', '북한', '정상', '관계', '시도'],
#  ['이스라엘', '네타냐후', '이란', '경고', '우리', '전투기', '도달', '가능', '지역'],
#  ['이스라엘', '네타냐후', '총선', '달', '앞두다', '우', '크다', '방문', '예정'],
#  ['트럼프', '탄핵', '보고서', '통화', '기록', '등장', '의문', '숫자'],
#  ['미국', '산업', '생산', '달', '제조업', '회복', '기대'],
#  ['셰이크', '살', 'AFC', '회장', '평양', '방문', '최휘', '국가', '체육', '지도', '위원장'],
#  ['신', '중국', '①', '차이나', '미라클', '최빈', '국서', 'G', '경제', '대국', '부상'],
#  ['UAE', '단교', '개월', '카타르', '왕래', '화물선', '허용'],
#  ['송환', '법', '반대', '홍콩', '집회서', '임', '행진곡', '울', '리다', '퍼지다'],
#  ['말레이시아', '총리', '비', '자금', '스캔들', '확산', '정국', '긴장', '고조'],
#  ['이스라엘', '군복무', '유대', '학교', '학생', '흉기', '찔리다', '숨다', '채', '발견'],
#  ['獨', '하원', '反', '이스라엘', '운동', '지다', '원', '단체', '지원', '중단', '결의'],
#  ['미군', '정찰기', '또', '한반도', '비행', '북', '방사포', '발사', '이후', '감시', '강화'],
#  ['암스테르담', '옴부즈맨', '홍등가', '출입', '금지', '연령', '정해', '이행'],
#  ['G', '홍콩', '문제', '알리', '홍콩', '시민', '릴레이', '시위', '예고'],
#  ['美', '태평양', '진출', '中', '견제', '하나', '日', '오키나와', '미사일', '훈련', '계획'],
#  ['터키', '주재', '러시아', '대사', '총격', '피습', '병원', '이송'],
#  ['유럽인', '난민', '테러', '가능성', '키우다', '인식'],
#  ['김영남', '우리', '민족', '위상', '과시', '뜨겁다', '분위기'],
#  ['이란', '최고', '지도자', '반정부', '시위', '美', '사주', '공작'],
#  ['볼턴', '美', '출신', 'IS', '신부', '귀국', '불허', '재', '확인', '시민권', '입증'],
#  ['부르키나파소', '무장', '괴한', '금광', '공격', '약', '사망'],
#  ['올랜도', '총기', '난사', '최소', '사망', '美', '사상', '최악', '총기', '참사'],
#  ['적극', '행정', '추진', '전략', '및', '성과', '공유', '대회', '참석', '이낙연', '총리'],
#  ['朴', '대통령', '한일', '합의', '소녀', '언급', '없다', '선동'],
#  ['민주', '국회의원', '재보선', '후보', '공모', '신청'],
#  ['프랑스', '마크', '롱', '이집트', '안정', '인권', '문제', '분리', '없다'],
#  ['박찬호', '현', '진', '승', '하', '생각', '나다'],
#  ['현행', '헌법', '다른', '점', '②', '지방자치', '경제민주화', '개념', '강화'],
#  ['곱다', '분투', '시즌', '서재덕', 'MVP', '덕', '큐리', '활짝', '웃다'],
#  ['트럼프', '유조선', '공격', '사소하다', '일', '이란', '충돌', '우려', '수위', '조절'],
#  ['이희호', '여사', '靑', '경호', '만료', '당분간', '경호', '유지'],
#  ['통일', '농구', '오늘', '친선', '남북', '대결', '김정은', '관전', '가능성'],
#  ['임도', '헌', '감독', '신영석', '중심', '똘똘', '뭉치', '한일전', '승리', '따내다'],
#  ['시위', '실탄', '발사', '정국', '불안', '홍콩', '증시', '대다', '하락'],
#  ['홍콩', '과격', '시위', '제보', '최고', '현상금', '걸리다'],
#  ['靑', '회담', '틀', '완전하다', '무시', '아니다'],
#  ['대북', '확성기', '방송', '전면', '재개', '접경', '긴장', '차'],
#  ['데얀', '김치우', 'OUT', '조영욱', 'IN', '서울', '과감', '재건', '성과'],
#  ['다당제', '효율', '일당', '체제', '中', '공산당', '망하다', '않다'],
#  ['문', '대통령', '북미', '합의', '이행', '국제사회', '협력', '새', '시대', '위해', '헌신'],
#  ['호날두', '노쇼', '유벤투스', '무책임', '거만', '비판', '수용', '어렵다'],
#  ['월드컵', '태극전사', '산책', '닭갈비', '피로', '해소'],
#  ['北', '미사일', '발사', '정부', '개성', '공단', '체류', '인원', '축소'],
#  ['朴', '대통령', '총선', '닷새', '평가', '평소', '짧다', '발언'],
#  ['한미', '수석', '대표', '협의', '위해', '출국', '이도훈'],
#  ['안철수', '천정배', '박지원', '동', '입당', '삼고초려'],
#  ['英', '존슨', '브렉', '시트', '완수', '뒤', '클린', '에너지', '혁명', '추진'],
#  ['문', '대통령', '아세안', 'APEC', '일정', '마치', '오늘', '저녁', '귀국'],
#  ['北', '개국', '파견', '하루', '강제노동'],
#  ['촛불', '민심', '받다', '들다', '국정', '운영', '촛불', '돌', '맞다', '문', '대통령'],
#  ['독재', '시작', '네이마르', 'PSG', '회장', '카바니', '이적', '요구'],
#  ['아시안', '게임', '만리장성', '맞서다', '농구', '단일', '팀', '이문규', '감독'],
#  ['스웨덴', '외교', '갈등', '스웨덴', '비자', '거부', '추방', '맞다', '불'],
#  ['한승혁', '⅔', '이닝', '실점', '역투', 'KIA', 'NC', '완파'],
#  ['이란', '트럼프', '무인기', '파괴', '확신', '찬', '거짓말', '처음', '믿다'],
#  ['박지수', 'WNBA', '코네티컷', '상대로', '점', '리바운드', '기록'],
#  ['MLB', '디애', '슬레', '류현진', '다음', '행선', '텍사스', '유력'],
#  ['한국', '가짜', '뉴스', '규제', '개인', '미디어', '통제', '입법', '반기'],
#  ['우상호', '박지원', '상견례', '당', '내놓다', '양보'],
#  ['美', '해군', '총장', '한일', '레이더', '갈등', '이견', '해소', '노력', '촉구'],
#  ['NBA', '즈', '개인', '최', '점', '넣다', '감격', '눈물'],
#  ['울산', '한마음', '축구', '대회', '개최', '여성', '노', '장부', '등', '팀', '참가'],
#  ['지역구', '후보', '재산', '이상', '김병관'],
#  ['朴', '대통령', '금주', '안보', '경제', '이중', '위기', '극복', '고삐', '죈다'],
#  ['터키', '독일', '러시아', '테러', '주도하다', '고위', 'IS', '지도자', '체포'],
#  ['화웨이', '한국', '기업', 'G', '생태계', '관련', 'MOU', '체결'],
#  ['구자철', '발목', '부상', '전력', '이탈', '아우', '크스', '비상'],
#  ['정지', '석', '양효진', '등', '프로배구', 'FA', '공시', '대다', '즐비'],
#  ['반년', '잊힌', '카슈끄', '사우디', '국제', '행사', '유력', '인사', '붐비다'],
#  ['獨', '외무', '홍콩', '시위', '격화', '모든', '당사자', '참다'],
#  ['한화', 'PS', 'vs', '넥센', 'PO'],
#  ['여야', '원내대표', '단', '방미', '추진', '美', '의회', '한반도', '평화', '설득'],
#  ['靑', '창조', '센터', '감찰', '주장', '감찰', '대상', '아니다', '중단', '사안'],
#  ['리비아', '긴장', '고조', '수도', '진격', '군벌', '트리폴리', '공항', '장악'],
#  ['홍콩', '경찰', '송환', '법', '시위', '입법', '의원', '추가', '체포', '석방'],
#  ['통일', '차관', '내일', '이산', '상봉', '시설', '개', '보수', '점검', '차', '금강산', '行'],
#  ['EU', '오만하다', '유조선', '두', '척', '피습', '관련', '최대한', '자제'],
#  ['원조', '친박', '文', '정부', '입각', '진영', '행안', '장관', '후보자'],
#  ['中', '美', '기업', '강제', '기술이전', '피해', '주장', '사실', '무근'],
#  ['파키스탄', '아내', '대상', '가볍다', '체벌', '허용', '법', '추진'],
#  ['문', '대통령', '유엔', '사무', '총장', '회담', '평창', '이후', '찾아오다', '봄', '고대'],
#  ['연세대', '고려대', '대학', '축구', 'U', '리그', '권', '역서', '정면', '대결'],
#  ['여야', '초선', '당선인', '연', '찬회', '박관용', '다', '선의', '순', '종말'],
#  ['北', '평양', '축구', '학교', '설립', '개교'],
#  ['美', '공화', '전당대회', '사흘', '미국', '우선', '합창'],
#  ['정부', '탈핵', '정책', '비판', '문서', '위장', '악성코드', '유포'],
#  ['C', '팰리스', '아스널', '완승', '이청용', '결장'],
#  ['대만', '총통', '선거', 'D', '막판', '관전', '포인트', '대학생', '귀향', '투표'],
#  ['슈퍼', '루키', '강백호', '남다', '경기', '신인', '최', '홈런', '신기록', '도전'],
#  ['이라크', '남부', '바스', '반정부', '시위', '부상', '항구', '차질'],
#  ['美', '행정부', '아프간', '병력', '감축', 'CIA', '역할', '확대', '놓다', '이견'],
#  ['英', '야당', '대표', '노딜', '브렉', '시트', '영국', '트럼프', '손아귀'],
#  ['군벌', '수장', '수도', '장악', '욕심', '갈림길', '선', '리비아'],
#  ['평양', '정상회담', '백', '화원', '영빈', '관', '도착', '문', '대통령'],
#  ['정의당', '아베', '정권', '규탄'],
#  ['오', '신', '환', '국회', '정상화', '진전', '협상', '가능', '주말', '전후', '동', '조율'],
#  ['美', '오하이오', '주립대', '교정', '총기', '괴한', '있다', '경고'],
#  ['센터', '김수지', '복근', '부상', '귀국', 'VNL', '주', '차다'],
#  ['北', '퍼스트레이디', '리설주', '개월', '공개', '행보'],
#  ['박지원', '靑', '中', '언론', '비판', '선전포고', '한중', '외교', '망치', '선'],
#  ['아시안', '게임', '경기장', '잔디', '점검', '김학범', '중동', '팀', '유리하다'],
#  ['회담', '베트남', '외교', '장관', '리용호', '북한', '외무'],
#  ['프로배구', '새내기', '황경민', '신인', '받다', '좋다'],
#  ['나라', '쪼개지다', '국민', '행복', '위협', '미국', '다수', '대선', '걱정'],
#  ['朴', '대통령', '지지율', '주', '유지', '역대', '최저', '치', '또', '경신'],
#  ['정상회담', 'D', '김정은', '완전하다', '비핵화', '의지', '판문점', '선언', '담기다'],
#  ['LA', '타임스', '현재', '다저스', '에이스', '커쇼', '뷸러', '아니다', '류현진'],
#  ['아가', '메', '즈', '비', '예나', '등', 'V', '리그', '외국인', '선수', '대거', '입국', 'KOVO'],
#  ['힐러리', '트럼프', '증오', '공포', '거래', '업자', '정치', '방화', '자행'],
#  ['도시', '사', '하소', '사제', '공중', 'ℓ', '성수', '뿌리'],
#  ['中', '건국', '주년', '역대', '최대', '규모', '열병', '힘', '과시'],
#  ['NC', '감독', '교체', '연패', '유영준', '감독대행', '데뷔전', '패배'],
#  ['제재', '풀리다', '이란', '산', '카펫', '미국', '수출'],
#  ['텍사스', '투수', '마이너', '논란', '탈삼진', '기록', '밀다', '눈살'],
#  ['류현진', '한국인', 'MLB', '올스타전', '선발', '이닝'],
#  ['지브롤터', '미국', '이란', '유조선', '압류', '요청', '거부'],
#  ['나란하다', '양복', '상의', '벗다', '지휘', '승자', '삼성', '이상민', '감독'],
#  ['프로농구', '선두', 'DB', '최', '하위', 'kt', '꺾다', '연승', '질주'],
#  ['中', '북미', '확실하다', '조치', '대북', '제재', '완화', '방법'],
#  ['대북', '제제', '중간', '점검', '⑤', '안보리', '제재', '이후', '北', '반발', '일지', '끝'],
#  ['파', '다르다', '트리플크라운', '현대', '캐피탈', '우리카드', '차다', '기선', '제압'],
#  ['축출', '수단', '독재자', '바', '시르다', '테러', '자금지원', '혐의', '조사', '받다'],
#  ['폭행', '혐의', '체포', '우리', '아스', '다저스', '복귀'],
#  ['북미', '정상회담', '여야', '표심', '이미', '반영', '부동', '층', '향배', '촉각'],
#  ['SUN', '야구', '국가대표팀', '전임', '감독', '선임', '퇴임'],
#  ['폴란드', '北', '노동자', '고용', '기업', '위법', '사례', '적발'],
#  ['북한', '인권', '기록', '센터', '현판', '北', '인권', '조사', '업무', '시작'],
#  ['네이마르', '메시', '브라질', '아르헨티나', '관광', '도우미', '나서다'],
#  ['캐나다', '외교', '당국자', '방북', '임', '현수', '목사', '문제', '논의'],
#  ['베트남', '언론', '아시안', '게임', '강', '박항서', '매직', '뉴스', '도배'],
#  ['아시안', '게임', '여자', '축구', '가을', '황금', '세대', '책임감', '새', '역'],
#  ['폼페이', '오', '中', '약탈', '전술', '알다', '중국', '충돌'],
#  ['김방훈', '자유', '한국', '제주도', '위원장', '도지사', '출마', '선언'],
#  ['IMO', '北', '탄도미사일', '발사', '관련', '통보', '없다'],
#  ['MBC', '류현진', '특집', '다큐', 'MLB', '전설', '듣다', '류현진'],
#  ['스웨덴', '사람', '말', '진짜', '스웨덴', '삶'],
#  ['다저스', '부상', '선수', '대거', '합류', '류현진', '힘', '실', '끄다'],
#  ['한국', '아시아', 'U', '여자농구', '강', '중국', '패배'],
#  ['프로농구', 'KBL', '음주', '운전', 'kt', '박철호', '경기', '출전'],
#  ['NBA', '매직', '공동', '창업', '올랜도', 'MLB', '구단', '유치', '추진'],
#  ['미사일', '공격', '시리아', '반군', '지도자', '여명', '사망'],
#  ['朴', '대통령', '취임', '국민', '경제', '언급'],
#  ['차이잉원', '추월', '라이', '칭더', '당선', '대만', '독립', '선포', '안해'],
#  ['이란', '美', '최대', '압박', '고', '비용', '보여주다', '해', 'WSJ'],
#  ['캐나다', '학교', '총격', '사망', '중태'],
#  ['여야', '출연', '연', '조직개편', '요청', '최', '기', '영', '후보자', '살펴보다'],
#  ['문', '대통령', '헌법', '기', '관장', '미소', '지다'],
#  ['밀워키', '간판', '옐', '리치', '파울', '타구', '맞다', '무릎', '골절', '시즌', '아웃'],
#  ['UAE', '내년', '화성', '탐사선', '발사', '우주개발', '우리', '문제', '해결'],
#  ['트럼프', '이란', '거래', '원하다', '제재', '완화', '여지', '언급'],
#  ['마르다', '침입', '여성', '배후', '중국', '관련', '단체', '있다'],
#  ['방', '북한', '러시아', '외무', '장관', '만나다', '김정은'],
#  ['살아나다', '트라우마', '롯데', '연패', '울', '판정', '울'],
#  ['웃다', '못', '김승기', '감독', '오세근', '많이', '다치다', '차다', '총력전'],
#  ['문', '대통령', '쇼트트랙', '최', '민정', '선수', '격려'],
#  ['김연경', '벨기에', '완패', '훈련', '못'],
#  ['시진핑', '이탈리아', '대통령', '정상회담', '일대일', '통해', '협력', '강화'],
#  ['국방부', '北', '한미', '훈련', '위협', '경거', '망동', '중단', '도발', '응징'],
#  ['NBA', '만년', '인자', '톰프슨', '점슛', '개', '신기록', '폭발'],
#  ['사드', '배치', '찬반', '당론', '못', '내놓다', '더', '민주', '지도', '부도', '온도', '차'],
#  ['평양', '정상회담', '정의용', '서훈', '기념', '촬영', '김정은'],
#  ['EU', '브렉', '시트', '연기', 'EU', '가다', '동의', '강조', '연기', '기간', '촉각'],
#  ['北', '종업원', '인신', '보호', '결론', '못내', '민변', '재판', '부', '기피', '신청'],
#  ['집', '나가다', '강하다', '류현진', '원정', '경기', '평균자책점', '점'],
#  ['네덜란드', '시리아', '체류', '자국', '아이', '송환', '문제', '놓다', '논란', '확산'],
#  ['팬텀', '싱어', '우승팀', '포르테', '디', '콰트로', '개', '도시', '투어', '공연'],
#  ['여자배구', '열기', '후끈', 'GS', '칼텍스', '홈', '경기', '시즌', '매진'],
#  ['얘기', '나누다', '정무수석', '민정', '수석'],
#  ['먼저', '승', '최태웅', '감독', '우승', '기회', '오다', '철저하다', '준비'],
#  ['홈런왕', '루스', '유니폼', '낙찰', '역대', '스포츠', '경매', '최고'],
#  ['궤도', '수정', '안철수', '지방', '강연', '본격', '활동재개', '아직'],
#  ['英', '냉동', '트럭', '비극', '베트남인', '시신', '모두', '송환'],
#  ['美', '남쪽', '국경', '우익', '민병대', '이민자', '구금'],
#  ['이란', '혁명', '수비대', '중동', '파견', '美', '항모', '위협', '아니다', '타격', '목표'],
#  ['우', '크다', '대선', '라이벌', '포로', '셴코젤', '렌스', '키', '유럽', '방문', '선거'],
#  ['與', '양', '향', '광주', '서다', '지역', '위원장', '직무', '대행', '임명'],
#  ['美', '동맹', '달러', '패권', '도전', 'EU', '인도', '對', '이란', '우회', '결제', '망', '구축'],
#  ['판문점', '선언', '함께', '걷다', '김정숙', '여사', '리설주', '여사'],
#  ['이해찬', '생활', '적폐', '누적', '공정사회', '만들다', '노력', '최선'],
#  ['靑', '내주', '초', '대북', '특사', '파견', '발표', '서훈', '국정원장', '유력'],
#  ['광란', '미국', '대학농구', '주인공', '세', '수녀'],
#  ['본회의', '출석', '염동열'],
#  ['朴', '대통령', '주', '미군', '특별하다', '친구', '브룩스', '같이', '가다'],
#  ['박원순', '선거', '사무소', '개소식'],
#  ['인민일보', '차이잉원', '뉴욕', '방문', '맹비', '미국', '장기', '말', '자처'],
#  ['힐러리', '지금', '선거', '대통령', 'TPP', '반대', '거듭', '천명'],
#  ['朴', '대통령', '모레', '국회', '연설', '北', '도발', '국민', '단합', '초당', '협조', '요청'],
#  ['김종민', '도로공사', '감독', '더', '체력', '이야기'],
#  ['곤', '닛산', '회장', '보석', '중', '일본', '도주', '레바논', '도착'],
#  ['서청원', '김무성', '권력자', '발언', '왜', '분란', '일으키다'],
#  ['북미', '회담', 'D', '외무', '北美', '합의', '다자', '회담', '확고하다'],
#  ['SK', '최정', '복귀', '임박', '이르다', '지명타자', '출전'],
#  ['프로축구', '부', '성남', '천적', '이랜드', '꺾다', '선두', '탈환'],
#  ['속보', '文', '대통령', '여야', '당', '대표', '日', '정부', '외교', '해결', '촉구'],
#  ['등판', '흔들다', '린드블럼', '제구', '흔들리다', '더', '준비'],
#  ['韓美', '연합', '훈련', '중단', '지침', '마련', '핵심', '변수', '北', '비핵화', '진전'],
#  ['배구', '연맹', '순천', 'KOVO', '컵', '운영', '대행', '업체', '입찰', '공고'],
#  ['오승환', 'MLB', '시범', '경기', '최종', '결장', 'ERA'],
#  ['트럼프', '美', '민주', '인프라', '투자', '의회', '조사', '양자', '택일', '압박'],
#  ['쿼터', '점포', '방', 'OK', '저축은행', '연패', '탈출', '신한은행'],
#  ['영상', '인종차별', '행동', '눈', '찢기다', '러시아', '코치', '경기', '징계'],
#  ['日', 'IoT', '기기', '바이러스', '감염', '심각', '달', '배', '급증'],
#  ['伊', '실세', '부총리', '살비', '조기', '총선', '원하다', '않다', '연정', '홍', '수습'],
#  ['루비', '오', '크루즈', '남다', '유일하다', '보수', '트럼프', '저지', '앞장서다'],
#  ['보츠와나', '등', '아프리카', '개국', '상아', '무역', '허용'],
#  ['文', '대통령', '노무현', '대통령', '꿈', '시민', '함께', '역사', '진전', '시키다'],
#  ['문', '대통령', '여기', '세종'],
#  ['KBL', '종료', '판정', '논란', '심판', '출전', '정지', '징계'],
#  ['AS', '모나코', '프랑스', '리그', '정상', '눈앞'],
#  ['퇴임', '앞두다', '슬로바키아', '대통령', '친', 'EU', '신당', '창', '계획'],
#  ['한국', '대만', '유', '소년', '배구', '교류', '타이중', '개최'],
#  ['나경', '복', '꼭', '해보다', '싶다', '트리플크라운', '범실', '줄'],
#  ['우상호', '거부권', '행사', '정치', '의도', '靑', '정쟁', '유발', '우려'],
#  ['패럴림픽', '김정숙', '여사', '아이스하키', '관람', '장애인스포츠', '많이', '알려지다'],
#  ['의원', '무', '노동', '무', '임금', '원칙', '체포', '동', '의안', '자동', '통과', '시키다'],
#  ['북', '마케도니아', '대선', '親', 'EU', '후보', '당선', 'EU', '가입', '물살'],
#  ['野', '가다', '설', '민심', '정권', '교체', '해달라다', '자만', '말르다', '쓴소리'],
#  ['흥국생명', '도로공사', '경기', '주목'],
#  ['女', '축구', '윤덕여', '감독', '끝', '아니다', '시작', '프랑스', '월드컵', '선전'],
#  ['朴', '대통령', '대북', '대화', '론', '쐐기', '대화', '위해', '준', '돈', '핵', '자금'],
#  ['트럼프', '금융', '자료', '의회', '제출', '이번', '금융', '사', '상대', '소송'],
#  ['북한', '인권', '정보', '센터', '北', '인권', '범죄', '절반', '자의', '체포', '구금'],
#  ['트럼프', '조롱', '대통령', '가짜', '문장', '온라인', '검색', '중', '나오다', '실수'],
#  ['배구', '올림픽', '대륙', '별', '예선', '남자', '부', '중국', '여', '자부', '태국', '개최'],
#  ['WNBA', '박지수', 'LA', '스파크스', '상대로', '출전'],
#  ['NBA', '경기', '도중', '난투극', '론도', '경기', '폴', '경기', '출전', '정'],
#  ['성균관대', '선후배', '장병철', '권', '순', '찬', '신진식', '감독', '대결', '기대다', '네'],
#  ['與', '예비', '후보자', '부정부패', '혐오', '발언', '젠더폭력', '불이익', '서약'],
#  ['트럼프', '日', '궁', '만찬', '참석', '밉다', '일', '동맹', '풍부하다', '재산'],
#  ['노란색', '유니폼', '만나다', '폭발', '손흥민', '스웨덴', '부탁'],
#  ['미국인', '기대수명', '감소', '사망률', '늘다'],
#  ['부패', '추문', '오스트리아', '극우', '국민당', '다시', '연정', '러브콜'],
#  ['소사', '이닝', '실점', 'LG', '롯데', '제압', '박용택', '무', '안타'],
#  ['유럽', '축구', '이내', '이적', '료', '유로', '시대', '오다'],
#  ['감독', '경질', '소용없다', 'NBA', '시카고', '연패', '수렁'],
#  ['日', '개월', '경상수지', '흑자', '흑', '자폭', '감소'],
#  ['양산', '구상', '마치다', '文', '중순', '캠프', '띄우다', '초', '출마', '선언'],
#  ['유럽', '핵', '합의', '명운', '건', '막판', '불꽃', '접촉', '美', '용인', '관건'],
#  ['배구', '남자', '대표팀', '감독', '공모', '임도', '헌', '코치', '단독', '지원'],
#  ['폭염', '덮다', '친', '이탈리아', '해충', '몸살', '사르데냐', '메뚜기', '떼', '습격'],
#  ['조기', '귀국', '女', '배구', '영', '안혜진', '부상', '회복', '주력'],
#  ['유엔', '北', '주민', '자의', '구금', '피해자', '판정', '석방', '촉구'],
#  ['中', '매체', '북미', '가까워지다', '중국', '의도', '부합'],
#  ['이스라엘', '무슬림', '美', '의원', '요르단강', '서안', '방문', '허용'],
#  ['류현진', '박찬호', '이렇다', '한국인', 'MLB', '개막전', '승'],
#  ['축구', '황제', '펠레', '브라질', '축구', '대표팀', '평가전', '해설', '나서다'],
#  ['양의지', '하루', '쉬', '갈다', '이흥련', '두산', '이적', '선발'],
#  ['탈레반', '포로', '피랍', '외국인', '각각', '석방', '교환', '평화', '촉진', '계기'],
#  ['日', '韓', '상응', '조치', '한국', '냉정하다', '대응', '주장'],
#  ['아시안', '게임', '동점골', '이민아', '선수', '속상하다', '태극', '낭자'],
#  ['사인', '어깨', '다치다', '일본', '투수', '마쓰자카', '장기', '이탈'],
#  ['문', '정부', '차', '산업혁명', '밑그림', '나오다', '사람', '중심', '지능', '경제'],
#  ['콜롬비아', '평화협정', '국민투표', '문구', '확정', '협정', 'ㆍ', '안정', '지지', '하나'],
#  ['독일', '소비자', '물가', '년', '상승', '약세', '지속'],
#  ['손흥민', '선발', '활약', '리그', '호골', '다음'],
#  ['이란', '美', 'CIA', '연', '계', '고정간첩', '체포', '사형', '선고'],
#  ['트럼프', '원금', '잭팟', '터지다', '카지노', '대부', '제공'],
#  ['美', '유럽', '호르무즈', '군', '파견', '추진', '이란', '해군', '합동', '훈련'],
#  ['북한', '농업', '연구원', '수학', '연구소', '준공'],
#  ['프랑스', '성', '매수', '처벌', '벌금', '성매매', '처벌', '법', '의회', '통과'],
#  ['추신수', '클리블랜드', '타수', '무', '안타', '시범', '경기', '타율'],
#  ['그래픽', '손흥민', '아시안', '최초', 'EPL', '두', '자릿수', '골'],
#  ['황희', '찬', '잘츠부르크', '오스트리아', '분데스리가', '연패', '달성'],
#  ['법원', '폭력', '남편', '석방', '부인', '살해', '멕시코', '부글부글'],
#  ['관리', '힘', 'SK', '김광현', '이닝', '무실점', '컨디션', '괜찮다'],
#  ['터키', '발', '주민', '보트', '그리스', '영해', '전복', '어린이', '등', '사망'],
#  ['밉다', '일', '무역', '협상', '내달', '크다', '틀', '합의', '목표'],
#  ['이집트', '헌법재판소', '창립', '주년', '기념', '세미나'],
#  ['MLB', '애틀랜타', '사', '극적', '뒤지다'],
#  ['KBO', '리그', '출신', '테임', '즈', '홈런', '타점', '강정호', '결장'],
#  ['프로농구', 'SK', '챔프', '사상', '최초', '패', '연승', '승'],
#  ['류현진', '콜로라도', '제물', 'QS', '생애', '홈런'],
#  ['트럼프', '인수위', '내각', '참여자', '로비', '못', '초', '강경', '서약', '마련'],
#  ['NBA', '미네소타', '즈', '두', '경기', '연속', '맹활약', '부활', '예감'],
#  ['제임스', '떠나다', '러브', '다치다', 'NBA', '클리블랜드', '개막', '연패', '늪'],
#  ['미국', '남다', '대다', '미얀마', '제재', '풀다', '달다', '갱신', '시한'],
#  ['총선', '일주일', '앞두다', '귀국', '朴', '대통령', '파다', '변수'],
#  ['류현진', '개인', '두', '완봉', '승', 'NL', '구단', '상대', '승리'],
#  ['EU', '北', '미사일', '추가', '발사', '비판', '추가', '도발'],
#  ['늪', '빠지다', '트럼프', '공화당', '주류', '외면', '지지율', '추락', '이중고'],
#  ['朴', '석방', '결의', '추진', '여진', '탄핵', '사과', '먼저', 'vs', '공', '방', '무의미'],
#  ['이란', '일각', '대미', '대화', '론', '제기', '前', '대통령', '적대', '풀다'],
#  ['日', '공정위', '스마트폰', '단말기', '약정', '할부', '시정', '요구'],
#  ['北', '인민군', '판문점', '대표', '부', 'UFG', '연습', '맹비', '백서', '발표'],
#  ['위기', '만나다', '두', '라이벌', '수원', 'vs', '서울', '올해', '슈퍼매치'],
#  ['터키', '에르도안', '미국', 'F', '팔면', '다른', '옵션', '택할'],
#  ['월드컵', '본선', '개국', '확대', '기회', '증가', 'vs', '질적', '저하'],
#  ['日', '매체', '임창용', '이대호', '김태균', '대다', '日', '최고', '외인', '선수'],
#  ['류중일', 'LG', '감독', '이형종', '공', '무섭다', '않다'],
#  ['아프간', '미군', '폭탄', '사망', '올해'],
#  ['바르다', '미래', '국감', '이슈', '통통', '통', '사', '토크', '정책', '소통'],
#  ['이인제', '탄핵', '역사', '법정', '미루다', '놓다', 'TV', '토론'],
#  ['게시판', '관훈클럽', '경남', '지사', '후보', '초청', '토론회'],
#  ['해결사', '김선형', '결승', '점포', 'SK', 'LG', '상승세', '찬물'],
#  ['인류학자', '아마존', '숲', '무엇', '보다'],
#  ['존슨', '英', '총리', '아일랜드', '브렉', '시트', '정상회담', '제안', '수용'],
#  ['사우디', '등', '아랍', '개국', '카타르', '개최', 'IPU', '총회', '불참'],
#  ['인사말', '민병', '욱', '이사장'],
#  ['교황', '공정하다', '평화롭다', '베네수엘라', '사태', '해법', '위해', '기도'],
#  ['획', '정위', '원장', '박영수', '선관위', '기', '조', '실장', '사실', '내정'],
#  ['프로농구', '현대', '모비스', '인삼공사', '꺾다', '연승', '질주'],
#  ['프로축구', 'K', '리그', '최종', '선수', '등록', '팀', '평균'],
#  ['朴', '대통령', '세월호', '행적', '보완', '제출', '특검', '發', '의혹', '유감'],
#  ['악성', '부채', '고려', '中', '성장', '률', '정부', '발표', '치', '절반', '불과'],
#  ['주간', '화제', '뉴스', '북핵', '대응', '中', '사드', '경제', '보복', '등', '관심'],
#  ['퇴임', '앞두다', 'ECB', '드', '부양책', '긍정', '경험', '여전하다', '필요'],
#  ['中', '여신', '폭발', '증가', '성장', '우선', '정책', '선회'],
#  ['그래픽', '러시아월드컵', '대표팀', '예상', '선발', '라인업'],
#  ['도이체방크', '중', '고', '위층', '자녀', '취업', '시키다', '사업', '따내다'],
#  ['홍콩', '시위', '지지', '中', '본토', '잇따르다', '체포'],
#  ['中', '인도', '등', '기후변화', '대응', '압박', '선진국', '돈', '더', '내야'],
#  ['입지', '좁다', '노수광', '데뷔', '끝내기', '홈런', '반전'],
#  ['더', '민주', '건', '보료', '직장', '지역', '구분', '없애다', '소득', '기준', '일원화'],
#  ['美', '유엔', '대사', '또', '여성', '파워', '이번', '공화당', '큰손', '크래프트'],
#  ['달라', '라마', '트럼프', '도덕', '원칙', '부족', '국제', '책임지다'],
#  ['새', '보수당', '서울시', '창', '당', '대회', '참석', '오', '신', '환', '지상욱'],
#  ['美', '뉴햄프셔', '경선', '승', '패', '이제', '관심', '사우스캐롤라이나', '네바다'],
#  ['IMO', 'ITU', '北', '탄도미사일', '발사', '관련', '통보', '없다'],
#  ['朴', '대통령', '네덜란드', '총리', '댓글', '월드컵', '협력', '꽃', '피우다'],
#  ['베', '이브', '류스', '류현진', '고교', '시절', '홈런', '개', '통산', '타율'],
#  ['케냐', '유명', '국립공원', '폭우', '외국인', '등', '숨다'],
#  ['이란', '외무', '美', '정부', '강경', '파가', '위험하다', '정책', '추구'],
#  ['펠', '리페', '손현', '종', '활약', 'KB', '손해', '보험', 'OK', '저축은행', '완파', '연승'],
#  ['캐나다', '총선', '비방', '가열', '트뤼', '보수당', '가장', '더럽다', '선거'],
#  ['트럼프', '이란', '외무', '장관', '만나다', '시기상조'],
#  ['프로축구', '수원', '서정원', '후임', '이임생', '유력', '최종', '계약'],
#  ['김성태', 'MB', '법정', '세우다', '정치', '보복', '정치', '풀이', '정권'],
#  ['정의', '윤', '소하', '원내대표', '합의', '추대', '임기', '연장'],
#  ['강정호', '루타', '경기', '연속', '타점'],
#  ['북러', '교역', '액', '지난해', '대비', '감소', '정세', '불안', '영향'],
#  ['축구', '꿈', '나무', '키우다', '군산', '청소년', '클럽', '팀', '달', '창단'],
#  ['과학', '대통령', '박정희', '신화', '정치', '후원자', '뿐'],
#  ['평양', '정상회담', '백', '화원', '영빈', '관', '도착', '문재인', '대통령', '내외'],
#  ['머리', '사다', 'NC', '손시헌', '의식', '있다', '∼', '입원', '예정'],
#  ['포틀랜드', '워싱턴', '꺾다', 'NBA', '서부', '콘퍼런스', '선두', '도약'],
#  ['日', '여당', '모든', '남성', '육아휴직', '사용', '의무', '법', '제화', '추진'],
#  ['이스라엘', '중도파', '지도자', '간츠', '총리', '후보', '지명', '경쟁', '유리'],
#  ['통일부', '北', '수해', '완전', '복구', '어렵다', '서두르다', '마무리'],
#  ['러시아', '최대', '외국인', '투자자', '왜', '반', '反', '푸틴', '운동', '가가'],
#  ['文', '의장', '일', '자다', '실력', '국회', '개헌', '촛불', '혁명', '완성'],
#  ['미군', '쿠르드', '시리아', '북부', '순찰', '철수', '뒤', '처음'],
#  ['한화', '벌써', '홈', '경기', '번', '매진', '경기', '연속'],
#  ['두산', '김재환', '경기', '연속', '아치로', '시즌', '홈런'],
#  ['알제리', '임시', '대통령', '대선', '실시', '국민대', '제안'],
#  ['북한', '탁구', '대표팀', '코리아', '오픈', '참가', '차', '입국'],
#  ['연장', '골', '레스터', 'FA', '컵', '강', '재경기', '더비카운티'],
#  ['핀란드', '라이프스타일', '체험', '이벤트'],
#  ['홍콩', '주둔', '중국군', '사령관', '극단', '폭력', '절대', '용납', '해', '경고'],
#  ['독일', '국제', '안보', '연구소', '중국', '해군력', '러시아', '따라잡다'],
#  ['여자', '축구', '조소현', '잉글랜드', '진출', '임박', '맨유', '알다'],
#  ['추미애', '공', '수', '처법', '만들어지다', '바라다', '檢', '권한', '분산', '국민', '열망'],
#  ['美', '슈퍼화요일', '샌더스', '돌풍', '약화', '추격', '여지', '남다'],
#  ['北', '당', '대회', '내일', '개막', '김정은', '시대', '공식', '선언'],
#  ['뉴욕', '센트럴', '파크', '거닐다', '국가', '기관', '방문', '차이잉원', '美', '지지', '과시'],
#  ['체포', '가능성', '내일', '귀국', '정면', '돌파', '전국', '시위', '촉구'],
#  ['PO', '앞두다', '우리카드', '현대', '캐피탈', '아가', '메', '즈', '문성민', '출격'],
#  ['프로축구', '전북', '진통', '끝', '손준호', '입단', '확정', '계약'],
#  ['朴', '대통령', '국회', '법', '막다', '어떻다', '국민', '지지', '호소'],
#  ['커리', '빠지다', '골든', '스테이', '트', '듀랜트', '쿡', '앞세우다', '브루클린', '승리'],
#  ['北', '美', '김정은', '제재', '반발', '뉴욕', '북미', '접촉', '통로', '완전', '차단'],
#  ['한국', '남자배구', 'U', '세계', '선수권', '중국', '패배'],
#  ['종아리', '부상', '베일', '유럽', '챔스리그', '강', '못', '뛰다'],
#  ['박지수', 'WNBA', '데뷔', '최', '다득점', '시카고', '득점'],
#  ['모잠비크', '발견', '항공기', '파편', '실종', '말레', '이기', '잔해', '가능성'],
#  ['佛', '혁명기념일', '니스', '광란', '트럭', '테러', '사망', '부상'],
#  ['일', '번', '여자', '축구', '대표팀', '지탱', '베테', '힘'],
#  ['장', '정석', '감독', '이정후', '중요하다', '해주다', '더', '예쁘다'],
#  ['국회', '열', '리다', '여야', '전당대회', '모드', '당권', '쟁탈전', '시동'],
#  ['홍준표', '너무', '나가다', '한국', '남북', '합의', '대응', '기조', '갈등'],
#  ['아시안', '게임', '건아', '효과', '누리', '남자', '농구', '몽골', '잡고'],
#  ['터키', '프랑스', '국적', 'IS', '포로', '본국', '송환'],
#  ['日', '야구', '영웅', '스즈키', '이치로', '메이저리그', '은퇴'],
#  ['발목', '부상', 'KB', '박지수', '안도', '한숨', '코트', '복귀'],
#  ['신인', '최', '홈런', '친', '알론소', 'NL', '신인상', '수상', '만장일치', '실패'],
#  ['中', '환', '구', '시보', '랴오닝', '함', '파키스탄', '매', '설', '유언비어'],
#  ['트럼프', '건네다', '조언', '다양성', '부의', '창조', '필수'],
#  ['EU', '네덜란드', '정부', '나이키', '조', '세', '특혜', '의혹', '심층', '조사', '착수'],
#  ['힐러리', '진영', '트럼프', '뭘', '감추다', '있다', '납세', '문제', '대다', '공세'],
#  ['정의용', '북한', '자다', '다녀오다'],
#  ['중국', '근', '무제', '반대', '운동', '블랙리스트', '화웨이', '알리바바'],
#  ['아시안', '게임', '이란', '끝내다', '김학범', '호', '회복', '훈련', '우즈베크'],
#  ['새롭다', '보수당', '서울시', '위원장', '김성동'],
#  ['조원우', '감독', '윤', '성빈', '김광현', '아니다', 'SK', '타자', '싸우다'],
#  ['긴급',
#   '朴',
#   '대통령',
#   '임',
#   '기내',
#   '헌법',
#   '개정',
#   '완수',
#   '국민',
#   '여',
#   '망',
#   '담다',
#   '개헌안',
#   '마련'],
#  ['브렉', '시트', '떠나다', '英', '대다', '증오범죄', '벌금'],
#  ['김형오', '국민', '울다', '보다', '당', '지도', '부와', '윗', '선', '때문', '참패'],
#  ['스페인', '극우', '성향', '복스', '득세', '유럽', '반', '난민', '포퓰', '리스트', '쾌재'],
#  ['최', '생애', 'PS', '보이', 'MLB', '탬파베이', '승만', '더'],
#  ['유시민', '檢', '압수수색', '심각하다', '오버', '조국', '법', '위반', '개도', '없다'],
#  ['볼턴', 'IS', '신부', '입국', '불허', '재', '확인', '시민권', '입증'],
#  ['마크', '롱', '동아프리카', '찾다', '경제', '군사', '협력', '강화', '中', '견제'],
#  ['中', '북미', '대화', '재개', '환영', '정치', '해결', '지지'],
#  ['리비아', '난민', '시설', '공습', '전쟁범죄', '용의', '선상', 'UAE'],
#  ['朴', '대통령', '中', '북핵', '불다', '의지', '실제', '조치', '연결'],
#  ['북한', '더', '많다', '위성', '발사', '달', '탐사'],
#  ['세인트루이스', '번', '김광현', '명문', '구단', '입단', '영광', 'SK'],
#  ['유럽', '챔스', '강', '이번', '주', '결정', '레알', '미소', '바르사', '울상'],
#  ['폼페이', '오', '김정은', '그', '팀', '현장', '배치', '제재', '계속', '언급'],
#  ['평양', '정상회담', '노동당', '청사', '방명록', '작성', '문', '대통령'],
#  ['프로농구', '순위', '유력', '변', '준형', '변', '코비', '변', '어빙'],
#  ['북악산', '산행', '문', '대통령'],
#  ['로이터', '中', '심야', '밉다', '중', '무역', '협상', '관련', '브리핑'],
#  ['에콰도르', '유가', '인상', '도시', '마비', '긴축', '정책', '반발', '여론', '거세지다'],
#  ['중앙', '타지키스탄', '교도소', 'IS', '조', '직원', '폭동', '여명', '사망'],
#  ['홍콩', '쇼핑몰', '친', '반중', '집회', '참가자', '몸싸움'],
#  ['프로축구', '인천', '무', '고사', '라운드', 'MVP', '영예'],
#  ['런던', '축구장', '열', '리다', 'MLB', '라이벌', '양키스', 'vs', '레드삭스'],
#  ['국무회의', '참석', '박능후', '보건복지부', '장관'],
#  ['나이지리아', '층', '건물', '붕괴', '초등생', '여명', '갇히다'],
#  ['컴퓨터', '배우다', '북한', '학생'],
#  ['개헌', '논의', '중요하다', '대통령제', '아니다'],
#  ['메이', '英', '총리', '말', '유럽의회', '선거', '참여', '비상', '계획', '준비'],
#  ['총선', '앞두다', '나이지리아', '지역', '선관위', '화재', '전소'],
#  ['경기', '출전', '앞두다', '부폰', '지단', '박치기', '은퇴'],
#  ['정부', '격상', '北', '조평통', '성명', '핵보유국', '주장', '궤변'],
#  ['파리', '가을', '공연', '즐기다'],
#  ['마르코스', '아들', '부통령', '선두', '다툼', '독재', '향수', '속지', '마르다'],
#  ['경기', '무패', '베다', '투', '감독', '우리', '옳다', '방향', '가다', '있다'],
#  ['UAE', '두바이', '택시', '전화', '호출', '내년', '중단', '앱', '전환'],
#  ['中', '공안', '부장', '중', '전회', '정치', '사회', '안정', '강조'],
#  ['손흥민', '올해', '마지막', '경기', '호골', '재다'],
#  ['박원순', '보편', '복지', '확대', '중앙정부', '나서다'],
#  ['김연', '철', '통일부장관', '면담', '윤상현', '외교', '통일', '위원장'],
#  ['서로', '격려', '북한', '여자', '양궁', '리', '커브', '팀'],
#  ['에르도안', '미사일', '도입', '철회', '안해', '차세대', '미사일', '검토'],
#  ['나경', '복', '펄펄', '우리카드', '한국전력', '완파', '연패', '탈출'],
#  ['정부', '北', '핵실험', '이후', '민간', '남북', '교류', '신청', '건', '보류'],
#  ['셰이크', '살', 'AFC', '회장', '평양', '방문', '北', '방북', '목적', '등', '언급'],
#  ['일본인', '좌완', '기쿠치', 'MLB', '시범', '경기', '데뷔전', '시속'],
#  ['박지원', '野', '대선', '후보', '단', '일화', '내년', '∼', '판단', '일'],
#  ['靑', '정무수석', '이정현', '만나다', '단식', '중단', '요청', '朴', '대통령', '걱정'],
#  ['터키', '쿠르드', '마을', '점령', 'vs', '쿠르드', '터키', '공격', '막다'],
#  ['朴', '대통령', '여야', '당', '대표', '내일', '오후', '북핵', 'ㆍ', '민생', '회담'],
#  ['미국', '中', '민주화', '운동', '봉쇄', '中', '공작원', '밉다', '감시', '망', '뚫다', '귀국'],
#  ['伊', '청년', '중', '직장', '없다', '교육', '받다'],
#  ['與',
#   '일본',
#   '특위',
#   '일',
#   '보다',
#   '경',
#   '제',
#   '침략',
#   '특',
#   '위로',
#   '명칭',
#   '변경',
#   '특사',
#   '파견',
#   '부적절'],
#  ['메르켈', '푸틴', '에르도안', '통화', '리비아', '내전', '문제', '논의'],
#  ['그래픽', '러시아월드컵', 'F', '조', '한국', '멕시코', '전력', '분석'],
#  ['이란', '군부', '잇다', '전쟁', '불사', '강경', '발언', '美', '오다', '대화', '차단'],
#  ['러시아', '극동', '최대', '향토', '박물관', '한국어', '서비스', '붐', '동참'],
#  ['속보', '文', '대통령', '여야', '대표', '초당', '협력', '소재', '부품', '산업', '경쟁력', '강화'],
#  ['中', '매체', '北', '예술', '단', '방중', '띄우기', '북한', '중국', '중시', '보여주다'],
#  ['프로야구', '시범', '경기', '궂', '날씨', '고척', '제외', '모두', '취소'],
#  ['손흥민', '달', '선수', '파전', '아궤로', '벤테케', '최대', '경쟁자'],
#  ['野', '퇴진', '당론', '딜레마', '당론', '정', '해법', '더', '꼬이다'],
#  ['靑', '은산', '분리', '완화', '공약', '파기', '알다', '진입', '규제', '개선', '이미', '언급'],
#  ['이탈리아', '집권', '대표', '유럽의회', '선거', '참패', '사퇴'],
#  ['대통령', '개헌안', '다음', '지방선거', '대선', '동시', '실시', '속보'],
#  ['사드', '불똥', '온', '中', '연변', '지다', '용제', '중단', '위기'],
#  ['文', '대통령', '北', '목선', '경계', '못', '국민', '제대로', '못', '알다', '철저', '점검'],
#  ['리버풀', '찾다', '손흥민', '활용', '법', '스피드', '살리다', '공간', '쇄도'],
#  ['與', '예', '결', '소위', '위원', '小', '소위', '여야', '당', '간사', '참여'],
#  ['朴', '대통령', '태릉선수촌', '방문', '리우', '올림픽', '대표', '단', '격려'],
#  ['해외', '미디어', '유료', '타깃', '젊다', '층', '겨눈', '영미', '언론사'],
#  ['스웨덴', '독일', '통', '창', '방패', '북아일랜드', '전서', '답', '찾다'],
#  ['與', '한국', '협상', '참여', '압박', '강온', '전략', '오늘', '임시국회', '소집', '요구'],
#  ['터키', '리라', '폭락', '사태', '비판', '외신', '기자', '법정', '출두'],
#  ['지동원', '아우', '크스', '다음', '시즌', '잔류', '가능성'],
#  ['삼성', '장원삼', '군', '등', '판서', '이닝', '실점', '직구', '최고', '㎞'],
#  ['프로농구', '챔피언', '차다', '경기', '세월호', '희생', '추모', '묵념'],
#  ['홍콩', '사업가', '공안', '사칭', '보이스피싱', '대다', '피해'],
#  ['AG', '남자', '축구', '조추첨', '개국', '누락', '조추첨', '다시'],
#  ['허정무', '차고', '김병지', '막다', '北', '축구공', '보내다', '빅매치'],
#  ['알자지라', '이란', '폭발물', '수거', '美', '영상', '사건', '뒤', '촬영'],
#  ['무디스', '오만', '국가신용등급', '정', '크다', '하향'],
#  ['넥센', '즌', '좌석', '입장료', '동결', '스카이박스', '인하'],
#  ['이라크', '친', '시위', '美', '대사관', '습격', '美', '폭격', '항의'],
#  ['모리뉴', '감독', '동안', '선수', '영', '입', '써다'],
#  ['나치', '피해', '떠나다', '유대인', '후손', '獨', '국적', '취득', '절차', '개선'],
#  ['북한', '권법', '테러', '방지법', '탄력', '받다', '여야', '논쟁', '재', '점화'],
#  ['송환', '법', '촉발', '홍콩', '여자친구', '살인', '범', '대만', '가다', '자수'],
#  ['오클랜드', '평균', '집값', '넘다', '이민', '인구', '증가', '원인'],
#  ['이방', '카', '보좌', '관', '비단', '실내', '신고', '환하다'],
#  ['중국', '미국', '산', '제품', '부터', '최고', '관세', '부과'],
#  ['주', '이스탄불', '한국', '총', '영사관', '한국', '애니메이션', '날', '개최'],
#  ['프로농구', 'DB', '이르다', '정규', '리그', '우승', '확정'],
#  ['트럼프', '불응', '지시', '먹히다', '의회', '자료', '제출', '동의', '측근'],
#  ['필리핀', '외무', '남중국해', '판결', '배제', '中', '대화'],
#  ['중국', '경제', '불안', 'IS', '보다', '무섭다', '건', '미국', '영향력'],
#  ['팔레스타인', '가자지구', '시위', '유혈', '참사', '평화', '멀다'],
#  ['오지환', '박해민', '포함', '아시안', '게임', '예비', '엔트리', '발'],
#  ['프로농구', 'DB', '사상', '최초', '최저', '연봉', '팀', '챔프', '우승', '도전'],
#  ['北', '무수단', '미사일', '보완', '시도', '㎞', '비행'],
#  ['국방부', '北', '고체', '연료', '로켓', '개발', '추진단', '엄중하다', '인식'],
#  ['김정숙', '여사', '아이스하키', '응원'],
#  ['천', '병혁', '야구', '세상', '고요', '폭풍', '류현진', '최대', '무기'],
#  ['베다', '투호', '아시안컵', '명단', '확정', '막판', '생존', '경쟁'],
#  ['朴', '대통령', '새', '도약', '위해', '끊임없다', '혁신', '이루다'],
#  ['일', '외교', '장관', '마드리드', '회담', '불발', '가능성', '일정', '조율', '어렵다'],
#  ['호날두', '골', '포르투갈', '헝가리', '승리', '연승', '행진'],
#  ['한화', '뒤지다', 'LG', '류중일', '감독', '승', 'NC', '유영준'],
#  ['구자철', '지동원', '선발', '아우', '크스', '호펜하임', '패배'],
#  ['총리', '김여정', '김영남', '등', '北', '고위', '대표', '단', '오찬'],
#  ['北', '박근혜', '정부', '남북관계', '최악', '지경', '비난'],
#  ['美', '국방부', '北', '미사일', '도발', '자제'],
#  ['민주', '혁신', '기술', '벤처기업', '차등', '의결권', '도입', '적극', '검토'],
#  ['손흥민', '시즌', '호골', '토트넘', '유럽', '챔스', '아포엘'],
#  ['밀리', '들다', '밀', '입국', '어쩌나', '英', '해협', '건너다', '소형', '보트', '척', '구조'],
#  ['안희정', '급등', '전인범', '논란', '악재', '직면', '文', '돌파', '카드', '찾다'],
#  ['김학용', '軍', '간부', '전역', '절반', '군인', '연금', '못', '받다'],
#  ['밉다', '중', '무역', '전쟁', '중국', '떠나다', 'EU', '기업', '불과'],
#  ['WP', '美', '이란', '산', '원유', '수입', '금지', '개국', '한시', '예외', '연장', '않다'],
#  ['당', '체제', '본회의', '與', '국민의당', '원샷', '법', '공조', '체제'],
#  ['정부', '北', '플루토늄', '생산', '주장', '안보리', '등', '대응', '방안', '협의'],
#  ['코트', '하나', '남북', '농구', '선수', '가슴', '평화', '번영'],
#  ['美', '폴란드', 'G', '네트워크', '안보', '협력', '화웨이', '견제'],
#  ['즐라탄', '행선', '정', '크다', '소식', '알다', '드리다'],
#  ['사우디', '예멘', '반군', '폭격', '반군', '수감자', '여명', '사망'],
#  ['남북정상회담', '주년', '기념', '학술', '회의'],
#  ['류현진', '콜로라도', '제물', 'QS', '생애', '홈런'],
#  ['지지자', '출마', '선언', '신용', '대통령', '직속', '청년', '위원장'],
#  ['맨유', '그', '리즈', '영', '입', '임박', '영국', '언론'],
#  ['사이영상', '디그', '롬', 'MLB', '메츠'],
#  ['민주', '당직', '대상', '공공기관', '수요', '조사', '없다'],
#  ['다저스', '신인', '포수', '스미스', '류현진', '호흡', '무척', '쉬', '다'],
#  ['꿀', '재미', '싸움', 'KB', '손보', '한국전력', '풀', '세트', '역전승'],
#  ['류중일', '감독', '칭찬', '오지환', '수비', '안정감', '생기'],
#  ['자유', '북한', '방송', '대표', '北', '함', '경북', '양강도', '폭우', '인명', '피해'],
#  ['김정은', '기상', '천', '외한', '국가', '최고', '지도자', '자리', '고안', '수도'],
#  ['레바논', '사흘', '거리', '시위', '경', '제', '난', '정권', '퇴진', '요구'],
#  ['강', '전북', '무너', '뜨다', '린', '골', '인천', '문', '선민', 'K', '리그', '운'],
#  ['朴', '대통령', 'TK', '민심', '달래다', '전대', '논란', '정치', '해석', '안타깝다'],
#  ['LG', '가을', '야구', '불안', '요소', '떠오르다', '천적', '두산'],
#  ['트럼프', '올해', 'EAS', '불참', '아시아', '미국', '존재', '감', '저하', '불보듯'],
#  ['홍콩', '선거', '혁명', '범', '민주', '진영', '싹', '쓸다', '친중파', '궤', '멸종', '합'],
#  ['뉴올리언스', '론도', '신들리다', '도움', '골든', '스테이', '트', '점차', '대다'],
#  ['문', '대통령', '국정', '지지도', '주', '리다', '지다', '리얼미터'],
#  ['中', 'G', '지배', '세계', '위험', '전직', '美', 'NSC', '장성', '주장'],
#  ['朴', '대통령', '고유', '전통', '문화', '산업', '옷', '입히다'],
#  ['파', '다르다', '요스바', '원하다', '현대', '캐피탈', '재수', '끝', '소원', '성취'],
#  ['정세균', '국회', '다운', '국민', '국회', '만들다', '때론', '강경하다', '필요'],
#  ['홍콩', '정부', '트럼프', '홍콩인', '권법', '서명', '맹비', '시위', '환호'],
#  ['LG', '박용택', '선발', '제외', '유강남', '지명타자', '선발', '출전'],
#  ['컴퓨터', '매달리다', '아들', '나무라다', '아버지', '호주', '가정', '비극'],
#  ['안방', '팬', '응원', '받다', '전북', '트리오', '고향', '온', '기분'],
#  ['문', '대통령', '러시아', '가스', '전기', '남북한', '일본', '공급', '수도', '속보'],
#  ['중국', '부동산', '규제', '약', '발', '상하이', '집값', '개월', '하락'],
#  ['세', '연상', '아내', '두다', '대선', '주자', '프랑스', '사랑', '문학', '보다'],
#  ['이승우', '바르셀로나', 'B', '승격', '가능성', '살', '있다'],
#  ['트럼프', '사위', '대선', '개입', '페북', '광고', '수준', '특검', '더', '해악'],
#  ['김정은', '오늘', '오후', '北', '돌아가다', '블라디', '역서', '오후', '환송', '행사'],
#  ['강등', '죽', '팬', '협박', '브라질', '축구', '구단', '사장', '사임'],
#  ['정치', '개혁', '제', '소위', '공직선거법', '개정안', '등', '심의'],
#  ['총리', '소득', '주도', '성장', '정책', '효과', '기대', '속도', '안나', '아쉽다'],
#  ['번', '타자', '최', '타점', '결승', '루타', '작렬', '경기', '연속', '장타'],
#  ['미군', '북부', '시리아', '철수', '준비', '일부', '이미', '이동'],
#  ['네덜란드', '상대방', '원하다', '않다', '성관계', '성폭행', '처벌', '추진'],
#  ['박건우', '삭발', '인제', '그만', '올해', '초반', '자다', '겁니다'],
#  ['밉다', '중정', '통화', 'G', '서다', '회담', '개최', '무역', '북핵', '논의'],
#  ['정부', '국민', '헌법', '자문', '특위', '운영', '경비', '책정'],
#  ['英', '브렉', '시트', '혼란', '날', '선', '獨', '佛', '분명하다', '입장', '제시'],
#  ['중러', '외교', '장관', '뉴욕', '동', '전략', '밀월', '강화', '공감'],
#  ['문', '대통령', '허다', '익범', '특검'],
#  ['일', '의원', '연맹', '의원', '환담', '이낙연', '총리'],
#  ['즐라탄', '주급', 'EPL', '사상', '최고', '액'],
#  ['리비아', '하프', '타르', '이탈리아', '깜짝', '방문', '콘테', '총리', '휴전', '촉구'],
#  ['최룡해', '이끌다', '北', '대표', '단', '사망', '카스트로', '조의'],
#  ['文', '대통령', '트럼프', '미사일', '지침', '탄두', '중량', '제한', '해제', '전격', '합의'],
#  ['이란', '중동', '주둔', '미군', '테러', '조직', '지정', '美', '맞다', '불'],
#  ['여의도', '검찰', '개혁', '촛불집회', '계속', '공', '수', '처', '설치'],
#  ['문', '대통령', '추격', '경제', '한계', '새', '가치', '선도', '창', '추다', '산업화'],
#  ['與', '총선', '참패', '원인', '진단', '위해', '언론', '상대', '설문조사'],
#  ['이낙연', '총리', '김종호', '감사원', '사무', '총장', '임명장'],
#  ['서아프리카', '말리', '군기지', '무장', '괴한', '피습', '최소', '사망'],
#  ['박기원', '대한항공', '감독', '강', '체제', '방심', '금물'],
#  ['대만', '이상', '고온', '중', '전력', '사용', '사상', '최대', '전력', '수급', '비상'],
#  ['한국전력', '배다', '연고', '수원', '잔류', '확정', '계약'],
#  ['터키', '야', '시리아', '북부', '군', '작전', '성', '토', '터키', '중동', '늪', '몰다', '넣다'],
#  ['월드컵', '미국', '매체', '한국', '참가', '의의', '두다', '수준'],
#  ['배구', '모르다', '비', '예나', '체력', '회복', '보강', '운동'],
#  ['국민의당', '박지원', '원내대표', '추대', '론', '급부', '러닝', '메이트', '김성식'],
#  ['문', '대통령', '사람', '중심', '경제', '포', '용성', '가능', '여성', '역량', '강화하다'],
#  ['태국', '군부', '주도', '개헌안', '또', '논란', '민정', '양은', '언제'],
#  ['박기원', '대한항공', '감독', '통합', '우승', '위해', '남다', '경기', '총력전'],
#  ['미국', '전국', '중계', '단골', '류현진', '점', '평균자책점', '위용', '뽐내다'],
#  ['이승엽', '야구', '장학재단', '대구', '공식', '출범'],
#  ['북한', '김정은', '당', '창', '건일', '맞다', '금수산', '궁전', '참배'],
#  ['심장병', '어린이', '돕기', '희망', '농구', '올스타', '개최'],
#  ['김태형', '감독', '포수', '론', '적', '우리', '투수', '파악', '먼저'],
#  ['남북통일', '농구', '나선', '박혜진', '진짜', '하나', '느낌', '받다', '싶다'],
#  ['프로농구', 'MVP', '두경민', 'PO', '바라보다', '결혼식', '날짜', '바꾸다'],
#  ['봄', '배구', '공격', '득점', '점', '박정아', '오늘', '점', '주다'],
#  ['문', '대통령', '한중일', '혁신', '기반', '성장', '세계', '경제', '주도하다'],
#  ['한화', '이글스', '연', '고지역', '학교', '야구', '용품', '지원'],
#  ['노경은', '등', '파다', '⅓', '이닝', '실점', '질롱', '끝내기', '승'],
#  ['듀랜트', '점', '골든', '스테이', '트', '밀워키', '꺾다', '선두', '고수'],
#  ['이승우', '사인', '요청', '쇄도', '이근호', '런웨이', '불참'],
#  ['최', '시즌', '루타', '종아리', '통증', '교체'],
#  ['작전', '승리', 'KB', '손해', '보험', '가빈', '앞세우다', '한국전력', '대다', '역전승'],
#  ['울산', '수원', '무승부', 'ACL', '행', '인천', '강원', '꺾다'],
#  ['화이트', '시즌', '최', '점', '프로농구', 'SK', '경쟁', '끝'],
#  ['지다', '카', '바이러스', '규명', '초', '저', '온', '전자현미경', '신', '약', '연구', '유용'],
#  ['브라질', '법정관리', '신청', '기업', '급증', '부채', '규모', '넘다'],
#  ['말컹', '멀티골', '경남', '대구', '극', '장골', '허용', '무승부'],
#  ['인종차별', '규탄', '아랑곳', '않다', '트럼프', '이기', '싸움'],
#  ['美', '매체', '류현진', '양키스', '홈런', '폭탄', '무너지다'],
#  ['증강현실', '①', '알파', '포켓몬', '고', '거', '세다', 'IT', '광풍'],
#  ['스타워즈', '알투디투', '같다', '로봇', '일본', '개발', '중'],
#  ['푸틴', '살', '사우디', '국왕', '통화', '원유', '시장', '공조', '지속', '합의'],
#  ['제임스', '버저비터', '클리블랜드', '토론토', '상대', 'PO', '연승'],
#  ['사우디', '석유', '시설', '공격', '주체', '지목', '신중', '이란', '책임'],
#  ['쌍둥이', '아빠', 'LG', '윌슨', '트윈스', '입단', '운명'],
#  ['국회', '의원', '실', '관계자', '입법', '사관', '몸싸움', '경찰', '출동'],
#  ['단독', '탈출', '북한', '식당', '종업원', '국내', '입국'],
#  ['정진석', '내일', '선', '이상', '중진', '비', '대위', '혁신', '인선', '논의'],
#  ['가자지구', '사흘', '충돌', '사망', '트럼프', '이스라엘', '지지'],
#  ['이스라엘', '가자지구', '어업', '구역', '축소', '로켓포', '발사', '대응'],
#  ['日', '방위', '초계기', '근접', '비행', '韓', '주장', '정확하다', '않다'],
#  ['그래픽', '남북정상회담', '오전', '주요', '일정'],
#  ['오스트리아', '우체국', '개인정보', '판매', '벌금'],
#  ['비', '예나', '점', '대한항공', '삼', '성', '화재', '승리', '연승'],
#  ['어나', '톰시', '판정', '승', 'IBK', '기업은행', '흥국생명', '완파'],
#  ['쿠', '어스', '필드', '극복', '류현진', '사이영상', '투표', '위도', '탈환'],
#  ['EU', '여성', '집행', '위원장', '후보', '브뤼셀', '방문', '융커', '투스크', '동'],
#  ['현금', '많다', '몇', '달', '뒤', '부도', '못', '믿다', '중국', '기업', '회계감사'],
#  ['프랑스', '이란', '탄도미사일', '개발', '놓다', '설전'],
#  ['日', '스즈키', '자동차', '검사', '부정', '대다', '리콜', '계획'],
#  ['AI', '월드컵', '생생하다', '현장', '중계'],
#  ['대다', '회의실', '열', '리다', '수', '석', '보좌', '관', '회의'],
#  ['김연', '철', '통일부장관', '악수', '윤상현', '외교', '통일', '위원장'],
#  ['멕시코', '대통령', '이민', '억제', '미국', '중미', '투자', '협상', '진전'],
#  ['카슈끄', '사건', '보은', '사우디', '왕세자', '파키스탄', '투자', '보따리'],
#  ['팬', '뽑다', '농구', '스타', '누구', 'KBL', '올스타전', '팬', '투표', '실시'],
#  ['민주', '한국', '행', '안위', '소위', '충돌', '법', '따르다', '소집', '날치기', '진행'],
#  ['보수', '야당', '열', '리다', '협치', '내각', '카드', '文', '대통령', '개각', '폭', '넓히다'],
#  ['조배숙', '평화', '걸음', '진전', '문재인', '정부', '일', '중', '가장', '자다', '일'],
#  ['中', '운동', '주년', '행사', '시진핑', '청년', '애국', '주의', '계승'],
#  ['KBS', '사장', '방위', '불', '출석', '성명', '발표', '한국', '위원'],
#  ['이세돌', '알파', '집중', '사람', '이기', '어렵다', '일문일답'],
#  ['귀환', '남북통일', '농구', '대표', '단'],
#  ['미국', '언론', '역사', '보내다', '류현진', '야구', '한류'],
#  ['실각', '위기', '네타냐후', '이스라엘', '총리', '유엔', '총회', '불참', '예정'],
#  ['광란', '시작', '버지니아', '전체', '톱', '시드', '배정'],
#  ['中', '당국', '미디어', '국가', '정책', '조롱', '말르다', '언론', '옥죄기'],
#  ['올해', '휴대폰', '국내', '생산', '량', '대다', '전의'],
#  ['남북', '공동', '행사', '가능성', '∼', '평양', '논의', '추진'],
#  ['알사드', 'AFC', '챔피언스리그', '강', '진출', '정우영', '풀타임'],
#  ['문성민', '헌신', '전광인', '적응', '현대', '캐피탈', '살리다', '날개', '공격수'],
#  ['LG', '개다', '노트', '겨냥', 'V', '티저', '광고', '편', '선전포고'],
#  ['마크', '롱', '측근', '중', '측근', '아프리카', '출신', '참모', '프랑스', '내각', '입성'],
#  ['獨', '美', '자동차', '관세', '결정', '연기', '경', '제위', '중요', '신호'],
#  ['이재오', '탈당', '제출', '내일', '오후', '무소속', '출마', '회견'],
#  ['靑', '문', '대통령', '리비아', '납치', '첫날', '구출', '최선', '다', '하라', '지시'],
#  ['KT', '스카이라이프', '알뜰폰', '판매', '전용', '요', '금제', '종', '출시'],
#  ['중국', '한류', '만화', '웹툰', '베이징', '국제', '도서전', '개', '社', '참가'],
#  ['악덕', '기업', '실명', '공개', '日', '하청', '기업', '가혹', '근무', '강요', '막다'],
#  ['K', '리그', '하나', '남다', '전북', '진화', '철옹성', '김민재', '덕', '웃다'],
#  ['쿠데타', '축출', '무르시', '이집트', '대통령', '사망'],
#  ['부활', '시동', '컵스', '다르빗슈', '시범', '경기', '이닝', 'K', '무실점'],
#  ['우원식', '원희룡', '제주', '지사', '면담'],
#  ['중국', '일대일', '주', '변국', '경제', '통로', '건설', '성과'],
#  ['박지원', '朴', '대통령', '구조조정', '정부', 'TF', '서다', '좋다', '도출', '해', '속보'],
#  ['헤인즈', '공백', '메우다', '메이스', '역대', 'PO', '외국인', '선수', '대타', '사례'],
#  ['트럼프', '나다', '김', '위원장', '만남', '고대', '北', '신년사', '화답'],
#  ['IS', '터키', '공세', '틈타다', '시리아', '수', '용소', '등', '공격', '모색'],
#  ['김우중', '회장', '빈소', '놓이다', '문재인', '대통령', '조화'],
#  ['ML', '크리스', '데이비스', '타석', '연속', '무', '안타', '역대', '타이', '기록'],
#  ['푸틴', '시민사회단체', '반발', '반', '테러', '법안', '패키지', '서명'],
#  ['잉크', '뒤지다', '쓸다', '알바니아', '총리', '의회', '답변', '중', '야', '의원', '공격', '받다'],
#  ['한국', '협상', '물', '건너가다', '패스트', '트랙', '강경', '투쟁', '론', '가열'],
#  ['쓰다', 'TV', '주파수', '농어촌', '무선인터넷', '쓴다'],
#  ['과학', '즐기다', '과학', '달', '행사', '여건', '풍', '성'],
#  ['김연경', '엑', '시바', '여자배구', '클럽', '챔피언십', '준우승'],
#  ['北', '통전', '부장', '김영철', '남북', '강', '대강', '대치', '장기', '가능성'],
#  ['朴', '대통령', '북핵', '갈수록', '악화', '주', '변국', '확실하다', '알다'],
#  ['호나우지뉴', '축구', '복귀', '수도', '단', '훈련', '없다'],
#  ['기', '정통부', '실험실', '창업', '사업', '공모', '총', '규모'],
#  ['그리스', '조기', '총선', '중도우파', '신민당', '승리', '전망'],
#  ['삼성', '전자', 'G', '기술', 'MWC', '공식', '방송', '단독', '생중계'],
#  ['이스라엘', '총선', '출구조사', '집권', '리쿠드당', '중도', '연합', '박빙'],
#  ['朴', '대통령', '핵탄두', '발언', '김정은', '겨냥', '핵무기', '망상', '버리다'],
#  ['더', '강력하다', '알파', '인간', '직관', '모', '방해', '학습'],
#  ['어디', '서든', '파티', '∼', 'LG', 'G', '씽', '큐', '붐', '박스', '스피커', '눈길'],
#  ['안갯속', '밉다', '중', '무역', '협상', '원', '달러', '또', '연', '고', '점'],
#  ['핵보유국', '회의', '베이징', '개막', '한반도', '비핵화', '논의', '가능성'],
#  ['포체', '티노', '토트넘', '감독', '손흥민', '윙백', '기용', '문제', '없다'],
#  ['고르바초프', '러시아', '서방', '물리', '비', '물리', '장벽'],
#  ['지기', '대결', '승자', '최태웅', '감독', '석진욱', '감독', '패'],
#  ['수원', '울산', 'FA', '컵', '강', '격돌', '대구', '전남도', '결승', '길목', '대결'],
#  ['한국인', '감독', '이끌다', '남수단', '축구', '대표팀', '대승', '축제', '분위기'],
#  ['트럼프', '리비아', '군벌', '하프', '타르', '통화', '사실', '지지', '선언'],
#  ['野', '단독', '국감', '강행', '출구', '찾기', '이정현', '단식', '걸리다', '돌'],
#  ['中', '산업', '생산', '증가', '율', '시장', '예', '상치', '하'],
#  ['KT', '영업', '이익', '돌파', '깜짝', '실적'],
#  ['트럼프', '취임식', '기부', '행렬', '일', '주', '일여', '목표', '액', '달성'],
#  ['복귀전', '강하다', '류현진', '밀워키', '⅔', '이닝', '실점'],
#  ['인공', '지능', '박지성', '나오다', 'KAIST', '서다', '세계', 'AI', '월드컵'],
#  ['우원식', '법', '사위', '체계', '자구', '심사', '폐지', '법안', '발의'],
#  ['카자흐', '대선', '토카', '예', '프', '현', '대통령', '압도', '승리', '득표'],
#  ['강원', 'FC', '조태룡', '대표', '비위', '의혹', '반박', '모든', '계약', '합법'],
#  ['현대', '모비스', 'SK', '꺾다', '연승', '단독', '선두', '질주'],
#  ['내전', '시리아', '다크', '투어', '리즘', '움직임', '우려', '제기'],
#  ['교황', '걸프', '긴장', '고조', '우려', '외교', '대화', '노력', '촉구'],
#  ['프로야구', 'NC', '롯데', '경기', 'KNN', '라디오', '생중계'],
#  ['G', '만난', '스마트', '카', 'MWC', '서도', '흥행', '몰이', '이어지다'],
#  ['현대', '캐피탈', '풀', '세트', '혈투', '대한항공', '극적', '역전승'],
#  ['LG', 'G', 'X', '듀얼', '스크린', '브라질', '출시', '중남미', '공략', '가속'],
#  ['英', '매체', '레스터', '시티', '후임', '사령탑', '히딩크', '물망'],
#  ['인터넷', '진흥', '우수', '정보보호', '기술', '지정', '제도', '시행'],
#  ['선두', '도로공사', '벼랑', '끝', 'GS', '칼텍스', '힘겹다', '풀', '세트', '승리'],
#  ['SKT', 'MWC', '서다', 'Gbps', '속도', 'G', '선보이다', '공공장소', '시연'],
#  ['朴', '대통령', '한국', '양적완화', '정책', '긍정', '검토', '증세', '마지막', '수단'],
#  ['NBA', '그린', '팀', '동료', '듀랜트', '언쟁', '경기', '출전', '정지', '징계'],
#  ['트럼프', '쿠르드', '공격', '터키', '경제', '파괴', '안전지대', '만들다'],
#  ['이야기', '나누다', '정동영', '장병완'],
#  ['중이온', '속기', '온', '핵심', '장치', '성능', '시험', '성공', '세계'],
#  ['연패', '탈출', '급선무', '조원우', '롯데', '감독', '불펜', '다', '대기'],
#  ['짐바브웨', '독재자', '무가베', '세로', '사망', '국민', '반응', '싸다', '늘다'],
#  ['與', '사개특위', '대신', '정개', '특위', '위원장', '맡다', '위원장', '홍영표'],
#  ['中', '올해', '들다', '美', '伊', '서다', '문화재', '점', '돌리다', '받다'],
#  ['SI', '선정', '올해', '스포츠인', 'NBA', '챔피언', '골든', '스테이', '트'],
#  ['그래픽', '축구', '대표팀', '월드컵', '유니폼', '공개'],
#  ['차', '청문회', '증인', '선서'],
#  ['中', '유엔', '마약', '단속', '기구', '수장', '우산', '혁명', '강경', '진압', '인물', '밀다'],
#  ['LG', '전자', '풀', '비', '로고', '상표', '출원', '광고', '활용'],
#  ['이란', '지다', '도부', '시위', '유혈', '진압', '민심', '악화', '관용', '대응'],
#  ['아픔', '딛다', '일어서다', '여자배구', '표승주', '역할', '자다', '알', '있다'],
#  ['독일', '시간', '인건비', 'EU', '서다'],
#  ['리용', '선', 'ITF', '신임', '총재', '한국', '팀', '평양', '초청'],
#  ['英', '언론', '中', '태평양', 'SLBM', '탑재', '잠수함', '투입', '태세'],
#  ['네이버', '뉴스', 'AI', '편집', '부당', '사람', '부분', '있다'],
#  ['현대', '모비스', '개막', '연승', '질주', '공동', 'KCC', '전자랜드', '패배'],
#  ['프로농구', '사령탑', '꼽', '우승', '후보', '막판', '연승', 'SK'],
#  ['인터넷', '업계', '구글', '반', '독점', '위반', '재', '조사해'],
#  ['나치', '제스처', '잉글랜드', '축구', '팬', '관중석', '영구', '퇴', '추다', '중', '징계'],
#  ['중국산', '모바일', '게임', '공습', '대작', '국내', '시장', '노리'],
#  ['北', '새롭다', '길', '압박', '美', '대응', '주목', '일단', '상황', '주시'],
#  ['한미', '北', '회담', '나오다', '인', '센티', '브', '제공'],
#  ['중국', '한류', '때리다', '지속', '중국', '진출', '韓', '기업', '치명', '타'],
#  ['트럼프', '납세', '자료', '요구', '일', '축', '국세청', '제출', '말르다'],
#  ['지중해', '난민', '표류', '사태', '재연', '난민', '타다', '獨', '난민', '구조선', '발', '묶이다'],
#  ['추신수', '대타', '나서다', '사다', '텍사스', '끝내', '기승'],
#  ['밉다', '트럼프', '이스라엘', '네타냐후', '통화', '이란', '위협', '논의'],
#  ['朴', '대통령', '절', '기념', '사', '북핵', '포기', '日', '합의', '이행', '강조', '전망'],
#  ['정상회담', 'D', '역사', '회담', '앞두다', '靑', '긴장', '태세', '유지'],
#  ['못', '믿다', '아파트', '관리', '비', '경기', '비리', '적발'],
#  ['탈', '석탄', '계획', '獨', '탈', '석탄', '동맹', '가입'],
#  ['네이버', '지도', '애플', '카', '플레이', '지원', '개시'],
#  ['별', '죽음', '지다', '구', '날씨', '영향', '끼치다'],
#  ['특징', '주', '관리종목', '해제', '대우조선', '해양', '강세'],
#  ['과학기술', '현장', '규제', '점검', '단', '출범'],
#  ['특징', '주', '강원랜드', '실적', '부진', '급락'],
#  ['류현진', '워싱턴', '상대로', '한미', '통산', '승', '도전'],
#  ['라면', '수출', '질주', '올해', '돌파', '확', '실시'],
#  ['北', '관영', '매체', '南', '통일', '농구', '방', '북단', '평양', '도착', '보도'],
#  ['日', '언론', '화웨이', '스마트폰', '부품', '약', '한미', '일', '기업', '의존'],
#  ['사면초가', '몰리', '이탈리아', '연정', '내부', '분열', '의원', '연쇄', '이탈'],
#  ['선관위', '수상', '경력', '부풀리다', '배현진', '서면', '경고'],
#  ['경기', '지표', '부진', '골드만삭스', '금리', '인상', '예상', '시기'],
#  ['네덜란드', 'EU', '우', '크다', '협력', '협정', '찬반', '국민투표'],
#  ['中', '랴오닝', '신', '기술', '개발', '구', '일대일', '첨단', '기술', '인력', '집결'],
#  ['페이스북', '가상', '화폐', '관심', '중국', '결제', '시장', '선점', '노리'],
#  ['네이버', '주소록', '암호', '잠그다', '기능', '도입'],
#  ['北', '조국', '통일', '민주주의', '전선', '결성', '돌', '중앙', '보고', '열', '리다'],
#  ['경남', '네게바', '아디다스', '탱고', '어워드', '호', '수상자'],
#  ['내년', '과학기술', '분야', '출연', '연', '예산'],
#  ['여자농구', '신한은행', '인천', '홈', '개막전', '승용차', '경품'],
#  ['개다', '노트', '호주', '인도', '출시', '여국', '확대'],
#  ['LG', 'G', '씽', '큐', '사전예약', '시작', '공', '지다', '원금', '최대'],
#  ['구글', 'AI', '진화', '어디', '당신', '얼굴', '알아보다', '일정', '알다', '주다'],
#  ['이산가족', '행사', '금강산', '시설', '개', '보수', '착수'],
#  ['코', '스타', '레스터', '시티', '홀로', '훈련', '중국', '갈다'],
#  ['어도비', '플래시', '말', '사라지다'],
#  ['삼성', '휴대폰', '평균', '판매', '가격', '국내', '해외', '선'],
#  ['통일', '대박', '론', '지지도', '하락', '국민', '북한'],
#  ['이란', '고위', '인사', '우리', '영국', '유조선', '억류'],
#  ['바르사', '듀오', '백승호', '이승우', '팀', '복귀', '프로', '계약', '준비'],
#  ['허수', '봉', '맹활약', '현대', '캐피탈', '삼', '성', '화재', '완승'],
#  ['강남', 'G', '빌리다', 'LGU', '일상', 'G', '길', '팝업', '스토어', '개장'],
#  ['육아휴직', '아빠', '아이', '더', '낳다', '데', '소', '극적', '스페인', '연구', '결과'],
#  ['美', '탈레반', '도하', '협상', '아프간', '철수', '영구', '평화', '정착', '논의'],
#  ['美', '코미디언', '존', '스튜어트', '트럼프', '어린이', '칭얼', '독설'],
#  ['KGP', '최대', '주주', '㈜', '제', '피', '셋', '투자', '변경'],
#  ['野', '손', '혜원', '탈당', '회견', '일제', '비판', '의원직', '사퇴'],
#  ['이스라엘', '이란', '새', '핵무기', '시설', '발각', '파괴', '이란', '거짓'],
#  ['카카오', '임지훈', '대표', '인공', '지능', '비서', '같다', '카카오', '톡', '만들다'],
#  ['유니', '테스트', 'SK', '하이닉스', '반도체', '장비', '공급', '계약'],
#  ['한국', 'MS', '서피스', '프로', '공개'],
#  ['브라운', '총리', '브렉', '시트', '이제', '시민', '나서다'],
#  ['도쿄', '국기관', '방문', '트럼프', '아베'],
#  ['LG', 'G', '실물', '사진', '유출', '둥글다', '모서리', '화면', '얇다', '베젤', '특징'],
#  ['프로야구', '잔', '경기', '일정', '발표', '정규', '리그', '종료'],
#  ['월드컵', '수비', '핵심', '박주호', '윙백', '풀백', '편하다'],
#  ['석', '유나', '데', '왜', '가난하다', '이라크', '반정부', '시위', '유전', '점거'],
#  ['NHN', '엔터', '기', '영업', '익', '↓'],
#  ['올해', '국내', '선사', '발주', '척', '중', '척', '중국', '수주', '한국', '척'],
#  ['찌', '다', '산다', '류현진', '강정호', '몸무게', '근육', '량', '증가'],
#  ['미래부', '우주', '기술', '기반', '창업', '지원', '과제', '공모'],
#  ['이라크', '친', '세력', '대통령', '사임', '배후', '미국', '주장'],
#  ['민주', '지다', '도부', '더', '짙어지다', '친문', '색채', '비주류', '실종'],
#  ['사우디', '관광', '비자', '개시', '열흘', '건', '발급'],
#  ['조', '세', '정책', '노동', '친', '적', '가야', '공정', '시장', '가액', '비율'],
#  ['이란', 'EU', '테러', '개입', '제재', '부과', '테러', '조직', '비호', '반박'],
#  ['해운', '사', '정부', '지원', '책', '밝히다', '해운', '동맹', '협상', '유리'],
#  ['카메룬', '네이션스컵', '결승', '진출', '이집트', '우승', '다툼'],
#  ['신', '영', '증권', '인', '크로스', '성장', '전망', '밝다', '목표'],
#  ['SNS', '돋보기', '북', '고위', '태', '영호', '귀순', '탈북', '수'],
#  ['우간다', '르완다', '영토', '침범', '르완다', '가짜', '뉴스', '반발'],
#  ['게시판', '미래에셋', '대우', 'All', 'Ways', '해외', '주식', '이벤트'],
#  ['모디', '시진핑', '인도', 'NSG', '가입', '객관', '평가', '해달라다'],
#  ['北', '남한', '전역', '사', '정권', '대형', '공격', '용', '드론', '개발'],
#  ['네이버', '라인', '프렌즈', '미국', '엑스포', '수출', '계약'],
#  ['伊', '지중해', '해상', '주민', '보트', '전복', '사망', '여명', '실종'],
#  ['삼성', '증권', 'GS', '리테일', '실적', '기대', '못', '미치다', '목표', '↓'],
#  ['伊', '오성운동', '민주당', '새', '연정', '정책', '합의', '난민', '정책', '완화'],
#  ['태국', '카페', '식당', '손님', '와이파이', '사용', '정보', '저장', '의무', '논란'],
#  ['더불다', '민주당', '의원', '인사', '조국'],
#  ['주중', '美', '대사관', '톈안먼', '시위', '주년', '조기', '게양'],
#  ['트럼프', '이민자', '열', '악', '처우', '논란', '그', '있다', '낫다'],
#  ['네이버', '소프트뱅크', '라인', '야후', '재팬', '경영', '통합', '합의'],
#  ['베다', '투', '우즈베크', '일부', '선수', '변화', '우리', '경기', '다시', '보이'],
#  ['LG', '유플러스', '유비', '쿼스', 'G', '용', '대다', '용량', '데이터', '전송', '장비', '개발'],
#  ['中企', '경기', '전망', '지수', '개월', '하락', '최대', '애로', '인건비', '상승'],
#  ['인터뷰', '신', '언', '北', '레짐', '체인지', '선택', '수', '있다', '정책', '옵션'],
#  ['배구', '협회', '보령', '이사회', '임도', '헌', '감독', '김태종', '코치', '승인'],
#  ['러시아', '관광', '청', '러시아', '유로', '기회', '세미나'],
#  ['러일', '외교', '국방', '장관', '회의', '이지스', '어쇼어', '쿠릴', '놓다', '갈등'],
#  ['북미', '정상회담', '합의', '결렬', '시장', '영향', '크다', '않다'],
#  ['한국전력', '감독', '가빈', '주장', '가빈', '뭐'],
#  ['주형', '환', '원샷', '법', '대기업', '제외', '실효', '떨어지다', '조', '기', '통과'],
#  ['커제', 'ㆍ', '박정환', '꺾다', '인터넷', '복면', '기왕', '정체', '알파'],
#  ['日', '서다', 'G', '환경', '장관', '회의', '개막', '日', '내년', '비닐봉지', '유료'],
#  ['북한', '참가', '국제', '유', '소년', '축구', '대회', '개', '단체', '공동', '응원'],
#  ['혼합', '복식', '남북', '단일', '팀', '한국', '상대로', '어떻다', '작전'],
#  ['MLB', '다저스', '사장', '류현진', '지금', '사이영상', '투구'],
#  ['한국', 'AI', '스피커', '시장', '급성', '올해', '세계', '톱', '전망'],
#  ['녹조', '라떼', '안전하다', '식수', '정수', '처리', '신', '기술', '개발'],
#  ['유럽의회', '선거', '돌풍', '브렉', '시트', '브렉', '시트', '이행', '통첩'],
#  ['기업', '생존', '전략', '새롭다', '수요', '창', '추다', '미래', '달리'],
#  ['국정원', '금강산관광', '재개', '유엔', '제재', '벌', '크다', '캐시', '문제', '연결'],
#  ['롯데', '제과', '아름답다', '가게', '사랑', '나눔', '기부', '판매'],
#  ['시리아', '공습', '터키', '통신사', '기자', '사망'],
#  ['톈안먼', '시위', '주년', '맞다', '미국', '탱크맨', '조각', '세워지다'],
#  ['가족', '문제', '근심', '깊다', '엘리자베스', '여왕', '썰렁하다', '성탄절'],
#  ['천정배', '박주선', '정동영', '포함', '연대', '추진', '합의'],
#  ['삼성', '갤럭시', 'S', '아이폰', 'X', '보다', '다운로드', '속도', '빨르다'],
#  ['이스라엘', '기', '공', '동위', '양자', '통신', '칩', '작물', '개발', '협력'],
#  ['황', '총리', '국회', '서비스', '법', '이번', '임시국회', '통과', '협조'],
#  ['민주', '입법', '전쟁', '하자', '한국', '국회', '복귀', '압박'],
#  ['왕년', '세이브', 'K', '로드', '멕시코', '리그', '재기', '도전'],
#  ['영상', '축구', '대표팀', '감독', '급부', '키케', '플로레스', '누구'],
#  ['남자배구', '올림픽', '세계', '예선', '타이스', '출격', '네덜란드', '대결'],
#  ['극', '장골', '첼시', '역전승', '루카쿠', '골', '맨유', '완승'],
#  ['알제리', '의회', '회의', '열다', '대통령', '직무', '대행', '지명'],
#  ['니카라과', '야권', '대화', '앞서', '정치범', '여명', '석방'],
#  ['안종범', '정책', '조정', '수석', '지난', '주말', '조용하다', '딸', '혼사', '치르다'],
#  ['日', '상', '장사', '주주', '우대', '제도', '운영', '역대', '최대'],
#  ['NH', '투자', '휠라', '코리아', '기', '성장', '세', '둔화', '전망', '목표', '↓'],
#  ['중국', '항저우', '실크', '박물관', '한국', '전통', '복식', '선보이다'],
#  ['朴', '대통령', '이란', '부통령', '양국', 'MOU', '실질', '성과', '구체화'],
#  ['공시가격', '인상', '임대', '등록', '다', '주택', '막판', '눈치', '작전'],
#  ['밉다', '중', '갈등', '복판', '선', '中', '화웨이', '멍', '완저우', '결백', '주장'],
#  ['김연경', '휴식', '한국', '여자배구', '네덜란드', '연속', '패배'],
#  ['이란', '압박', '미국', 'B', '전략', '폭격기', '카타르', '도착'],
#  ['웨어', '러블', '태블릿', '통신', '가입자', '쑥쑥'],
#  ['민주', '전대', '룰', '전쟁', '시작', '차기', '지다', '도부', '역할', '론', '갑론', '박도'],
#  ['靑', '욕', '먹다', '좋다', '각오', '국민', '믿다', '달려오다'],
#  ['집', '계약', '대출', '막히다', '규제', '첫날', '은행', '문의', '이어지다'],
#  ['가빈', '산체스', '같다', '조', '경쟁', '트', '아웃', '참가'],
#  ['증시', '신', '상품', '한국', '운용', '벨기에', '정부', '기관', '건물', '투자', '펀드', '출시'],
#  ['파키스탄', '시장', '폭탄', '테러', '최소', '사망'],
#  ['한미', '일', '북핵', '대표', '뉴욕', '협의', '국', '공조', '방안', '논의'],
#  ['페이스북', '개인정보', '유출', '한국', '피해자', '최대'],
#  ['디그', '롬', 'ERA', '시즌', '끝', '류현진', '⅔', '이닝'],
#  ['이정현', '朴', '대통령', '최', '순', '실', '조속', '귀국', '적극', '수사', '건의', '속보'],
#  ['김종인', '朴', '대통령', '휴가', '기간', '인사', '쇄신', '구체', '방안', '마련'],
#  ['기', '정통부', '세계', '전파', '통신', '회의', 'G', '주파수', '국제', '분배', '합의'],
#  ['힉스', '입자', '신의', '입자', '까닭'],
#  ['曺', '청문회', '오', '신', '환', '제안', '靑', '부정', '∼', '서다', '더', '못', '미루다'],
#  ['문화', '누리', '카드', '부터', '전국', '발급', '혜택'],
#  ['베로나', 'AC', '밀란', '꺾다', '강등권', '탈출', '시동', '이승우', '벤치'],
#  ['감독', '배', '주먹', '툭', '김태형', '감독', '이르다', '유행'],
#  ['IS', '부활', '우려', '현실', '터키', '공격', '틈타다', '활동', '재개'],
#  ['통통', 'TV', 'G', '바뀌다', '뭐', '좋다', '초', '고속', '초', '저', '지연', '초', '연결'],
#  ['위협', '구', '격분', 'MLB', '감독', '퇴장', '상대', '팀', '감독', '돌진', '시도'],
#  ['SK', '텔', '링크', '갤럭시', 'S', '구매', '중고', '폰', '팔면', '최대', '추가', '보상'],
#  ['LG', '생건', '숨', '중국', '온', '오프', '진출', '본격'],
#  ['파울', '선언', '항의', '유니폼', '찢다', '벤슨', '벌금'],
#  ['클린턴', '트럼프', '지지율', '박빙', '보유', '실탄', '크다', '차'],
#  ['프로배구', '외국인', '선수', '트', '아웃', '초', '캐나다', '토론토', '개최'],
#  ['北', '김정은', '방직', '공장', '시찰', '다른', '나라', '가방', '제품', '견줄'],
#  ['아시안', '게임', '금메달', '깨', '물어보다', '아들', '이정후', '영상', '찍다'],
#  ['유승민', '안철수', '비상', '행동', '출범', '바르다', '미래', '지붕', '두', '살림'],
#  ['한국', '야구', 'U', '세계', '선수권', '슈퍼', '라운드', '일본', '석', '패'],
#  ['묘', '타이밍', '트럼프', '등', '돌리다', '코언', '누가', '지다', '보다'],
#  ['LGU', 'G', '전파', '내달', '발사', '스마트폰', '통한', '상용'],
#  ['중국', '경기', '둔화', '춘제', '해외여행', '급증', '한국', '인기'],
#  ['금융', '안정', '합의', '없다', '브렉', '시트', '금융시장', '안정', '영향'],
#  ['레바논', '군', '영', '공', '침범', '이스라엘', '드론', '발포'],
#  ['전광인', '공수', '맹활약', '현대', '캐피탈', '연승', '챔프', '우승'],
#  ['헬로모바일', '요금', '할인', '고객', '기본', '료', '추가', '적립'],
#  ['회담', '일자', '잡히다', '남북정상회담', '준비', '박차'],
#  ['소말리아', '수도', '또', '폭탄', '테러', '최소', '사망'],
#  ['캄보디아', '한인', '분규', '사태', '종결', '회장', '김현식', '씨'],
#  ['대한민국', '농구', '협회', '공인', '신인', '심판', '수련', '생', '모집'],
#  ['민주', '남북정상회담', '후속', '작업', '박차', '입법', '예산', '뒷받침'],
#  ['美', '대선', 'TV', '토론', '美', '언론', '힐러리', '승', '트럼프', '번번이', '미끼', '물어'],
#  ['SKT', '가장', '혁신', '에지', '컴퓨팅', '전략', '선정'],
#  ['LGU', 'X', '스킨', '직접', '촬영', '출사', '이벤트', '개최'],
#  ['황교안', '출마', '질문', '세례', '국정', '안정', '요지부동'],
#  ['정진석', '경제', '타이밍', '추경안', '최대한', '신속', '처리'],
#  ['北', '차', '핵실험', '준비', '징후', '개월', '또', '핵', '도발', '하나'],
#  ['인사말', '황창규', '회장'],
#  ['中', '협상', '대표', '류허', '美', '추가', '관세', '연기', '환영', '실무', '팀', '내주', '동'],
#  ['美', '대만', '총통', '선거', '중국', '영향력', '행사', '우려', '대중', '경고'],
#  ['샤오미', '웨어', '러블', '시장', '세계', '애플', '핏', '비트', '꺾다'],
#  ['최', '순', '실', '귀국', '조사', '속결', '비', '서다', '밝혀지다'],
#  ['올해', '금', '펀드', '수익률', '최', '하위', '강', '달러', '여파'],
#  ['더', '민주', '당비', '月', '서다', '인상', '고민', '속사정'],
#  ['한국', '원', '조', '규모', '미국', '앞서다', '라오스', '한류', '열풍', '본격', '점화'],
#  ['전격', '리비아', '여명', '사망', '군벌', '트리폴리', '외곽', '공습'],
#  ['민주', '콩고', '수도', '킨샤사', '폭우', '사망'],
#  ['문', '대통령', '장성', '진급', '삼정', '검', '수여', '신뢰', '받다', '軍', '이끌다'],
#  ['번리', '맨시티', '맨유', '첼시', 'EPL', '도약', '파란'],
#  ['프로농구', 'SK', 'LG', '꺾다', '경', '기차', '추격', '최준용', '크다'],
#  ['이통', '사', '엇갈리다', '실적', 'LGU', '쑥쑥', 'SKT', '제자리', 'KT', '주춤'],
#  ['특징', '주', '크라운', '제과', '인적', '분할', '지주사', '전환', '결정', '급등'],
#  ['유럽', '강타', '랜섬', '웨어', '국내', '유입', '제약', '사도', '감염'],
#  ['윤호중', '日', '수출', '규제', '한일', '항공', '노선', '운항', '최대', '축소', '전망'],
#  ['일본', '개헌', '세', '몰이', '집회', '아베', '동영상', '메시지'],
#  ['코스피', '대다', '강', '보합', '마감'],
#  ['노영민', '당원', '자격정지', '개월', '신기남', '당원', '자격정지', '개월'],
#  ['칠레', '컨페드컵', '차다', '젊다', '독일', '무승부'],
#  ['朴', '대통령', '장', '차관', '우린', '공동', '운명', '체', '기적', '드라마', '쓰다'],
#  ['女', '배구', '대표팀', '올림픽', '직행', '티켓', '따다', '세계', '예선', '참가', '차', '출국'],
#  ['일반', '가맹', '점도', '대기업', '똑같다', '카드', '수수료', '율', '적용', '받다'],
#  ['아프리카', '말리', '건물', '붕괴', '사망'],
#  ['황석영', '작가', '미국', '문학', '축제', '국문학', '알리'],
#  ['추신수', '어깨', '수술', '즌', '준비', '문제', '없다'],
#  ['IBM', '시스코', '사물인터넷', 'IoT', '기술', '개발', '제휴'],
#  ['우버', '국내', '음식', '배달', '시장', '도전', '우버', '츠', '출시', '준비'],
#  ['평양', '정상회담', 'D', '성악', '전공', '남북', '퍼스트레이디', '음악', '하나'],
#  ['강정호', '점', '홈런', '폭발', '시즌', '호'],
#  ['中', '중앙', '경', '제', '공', '작', '회의', '폐막', '내년', '적극', '재정정책', '펼치다'],
#  ['휴일', '불청객', '울산', '미세먼지', '주의보', '발령'],
#  ['靑', '北', '장거리', '미사일', '발사', '징후', '우선', '순위', '두다', '감시'],
#  ['볼넷', '싫어하다', '류현진', '더', '놀라다', '기록', '잔루율'],
#  ['김수영', '신임', '한국', '출판', '문화', '산업', '진흥', '원장'],
#  ['최악', '패배', '맨시티', '과르디올라', '우승', '도전', '물', '건너가다'],
#  ['신간', '한반도', '평화', '오디세이'],
#  ['원', '달러', '환율', '강', '보합', '성장', '전망', '조정', '투자', '심리', '위축'],
#  ['NH', '투자', '환율', '넘다', '외국인', '셀', '코리아'],
#  ['가극', '금강', '낭독', '공연', '간담'],
#  ['인스타', '스토리', '사진', '동영상', '없이', '글', '만들다'],
#  ['감옥', '갇히다', '트럼프', '예멘', '대통령'],
#  ['LG', '파죽', '연승', '최', '하위', '삼성', '연패'],
#  ['英', '극우정치', '잇다', '밀크셰이크', '세례', 'EU', '잔류', '파', '소행'],
#  ['아르헨티나', '다음', '달', '중남미', 'K', '팝', '대회', '개팀', '참가'],
#  ['요금', '인상', '가입자', '늘리다', '음원', '업계', '연말', '총력', '마케팅'],
#  ['만', '기', '임박', '연', '넘다', '대출', '안전', '망', '대출', '전환'],
#  ['北', '개성', '공단', '폐쇄', '자산', '동결', '남', '인원', '철수', '완료'],
#  ['오', '신', '환', '준', '연동', '비례대표제', '공', '수', '처', '기소권', '제한', '대타협'],
#  ['춘천', '드론', '체험', '명소', '드론', '페스티벌', '내달', '개최'],
#  ['朴', '대통령', '탈북민', '통일', '시험', '충분하다', '수용', '체계', '갖추다'],
#  ['伊', '정국', '위기', '분수령', '대통령', '정당', '수뇌부', '새', '연정', '논의'],
#  ['알뜰폰', '위기', '감', '커지다', 'CJ', '헬로', '사업자', '협회', '마찰', '탈퇴'],
#  ['예멘', '내전', '출구', '모색', '美', '친', '반군', '직접', '협상', '추진'],
#  ['佛', '르노', '日', '닛산', '차', '경영', '체계', '개편안', '반대', '갈등', '심화'],
#  ['NYT', '트럼프', '김정은', '두다', '오', '판', '나쁘다', '베팅', '이어지다'],
#  ['가상현실', '즐기다', '서울', '강남', 'VR', '방', '생기'],
#  ['코스피', '선', '회복', '코스닥', '거래', '일', '반등'],
#  ['美', '아이오와', '경선', '입구', '조사', '공화', '트럼프', '크루즈', '루비', '오', '순서'],
#  ['이해찬', '북미', '회담', '좋다', '결과', '바랬는데', '아쉽다'],
#  ['게시판', '삼정', 'KPMG', 'IPO', '성공', '전략', '세미나'],
#  ['증시', '신', '상품', 'SK', '증권', '최고', '수익', '추구', 'ELB', '등', '종', '공모'],
#  ['개다', 'S', '신형', 'LG', 'V', '내달', '동시', '출시', '유력', '가격', '대다'],
#  ['U', '드컵', '일본', '이탈리아', '비기다', '조', '강행'],
#  ['KT', '배터리', '절감', '기술', '경품', '이벤트', '승용차'],
#  ['LG', '전자', '보급', '스마트폰', 'K', '시리즈', 'CES', '서다', '공개'],
#  ['일', '연구', '팀', '지구', '유출', '산소', '달', '도달', '사실', '확인'],
#  ['범', '정부', '화재', '안전', '특별', '대책', '발표'],
#  ['흐리다', '무덥다', '주말', '충북', '곳곳', '피', '객', '북적'],
#  ['제', '서강', '언론인', '시상식'],
#  ['원', '익', '모', '멘티', '브', '인수', '검토', '결정', '사항', '없다'],
#  ...]

# %%
from keras.preprocessing.text import Tokenizer 
max_words = 35000 
tokenizer = Tokenizer(num_words = max_words) 
tokenizer.fit_on_texts(X_train) 
X_train = tokenizer.texts_to_sequences(X_train) 
X_test = tokenizer.texts_to_sequences(X_test)

# %%
import numpy as np 
y_train = [] 

for i in range(len(train['topic_idx'])): 
    if train['topic_idx'].iloc[i] == 0: 
        y_train.append([1, 0, 0, 0, 0, 0, 0]) 
    elif train['topic_idx'].iloc[i] == 1: 
        y_train.append([0, 1, 0, 0, 0, 0, 0]) 
    elif train['topic_idx'].iloc[i] == 2: 
        y_train.append([0, 0, 1, 0, 0, 0, 0]) 
    elif train['topic_idx'].iloc[i] == 3: 
        y_train.append([0, 0, 0, 1, 0, 0, 0]) 
    elif train['topic_idx'].iloc[i] == 4: 
        y_train.append([0, 0, 0, 0, 1, 0, 0]) 
    elif train['topic_idx'].iloc[i] == 5: 
        y_train.append([0, 0, 0, 0, 0, 1, 0]) 
    elif train['topic_idx'].iloc[i] == 6: 
        y_train.append([0, 0, 0, 0, 0, 0, 1]) 
        
y_train = np.array(y_train)

# %%
from keras.layers import Embedding, Dense, LSTM 
from keras.models import Sequential
from keras.preprocessing.sequence import pad_sequences 
max_len = 20 # 전체 데이터의 길이를 20로 맞춘다 
X_train = pad_sequences(X_train, maxlen=max_len) 
X_test = pad_sequences(X_test, maxlen=max_len)

# %%
model = Sequential() 
model.add(Embedding(max_words, 100)) 
model.add(LSTM(128)) 
model.add(Dense(7, activation='softmax')) 
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy']) 
history = model.fit(X_train, y_train, epochs=10, batch_size=10, validation_split=0.1)
# Out:
# Epoch 1/10
# 4109/4109 [==============================] - 264s 63ms/step - loss: 0.8698 - accuracy: 0.6891 - val_loss: 0.4824 - val_accuracy: 0.8401
# Epoch 2/10
# 1667/4109 [===========>..................] - ETA: 2:25 - loss: 0.2456 - accuracy: 0.9182

# %%
predict = model.predict(X_test)
topic = []
for i in range(len(predict)):
    topic.append(np.argmax(predict[i]))

# %% [markdown]
# ## 재출 데이터 생성

# %%
submission = pd.read_csv('Dataset/sample_submission.csv')

# %%
submission['topic_idx'] = pred
submission.tail(10)
# Out:
#       index  topic_idx
# 9121  54775          0
# 9122  54776          2
# 9123  54777          2
# 9124  54778          2
# 9125  54779          2
# 9126  54780          3
# 9127  54781          6
# 9128  54782          4
# 9129  54783          0
# 9130  54784          2

# %%
submission.to_csv('submission/LSTM_0708.csv',index = False)
